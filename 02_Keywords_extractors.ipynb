# %% [markdown]
# # Extract Keywords - BART X BERT

# %%
import os
import re
import json
from tqdm.auto import tqdm
from langchain.text_splitter import RecursiveCharacterTextSplitter
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForTokenClassification

# %%
file_path = './data/context_id_train_dev_en.json'

with open(file_path, 'r') as f:
    data = json.load(f)

print(f"Total num: {len(data)}")
data[:5]
# Out:
# Total num: 13932
# [{'context': 'WikiLeaks () is an international non-profit organisation that publishes secret information, news leaks, and classified media provided by anonymous sources. Its website, initiated in 2006 in Iceland by the organisation Sunshine Press, claims a database of 10 million documents in 10 years since its launch. Julian Assange, an Australian Internet activist, is generally described as its founder and director. Kristinn Hrafnsson is its editor-in-chief.',
#   'id': 0},
#  {'context': 'The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945. Following the Potsdam Declaration by the Allies on 26 July 1945 and the refusal of Japan to surrender under its terms, the United States dropped atomic bombs on the Japanese cities of Hiroshima and Nagasaki on 6 and 9 August respectively. With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies. Tribunals were set up by fiat by the Allies and war crimes trials were conducted in the wake of the war both against the Germans and the Japanese.',
#   'id': 1},
#  {'context': "The exact number of Arab casualties is unknown. One estimate places the Arab death toll at 7,000, including 3,000 Palestinians, 2,000 Egyptians, 1,000 Jordanians, and 1,000 Syrians. In 1958, Palestinian historian Aref al-Aref calculated that the Arab armies' combined losses amounted to 3,700, with Egypt losing 961 regular and 200 irregular soldiers and Jordan losing 362 regulars and 200 irregulars. According to Henry Laurens, the Palestinians suffered double the Jewish losses, with 13,000 dead, 1,953 of whom are known to have died in combat situations. Of the remainder, 4,004 remain nameless but the place, tally and date of their death is known, and a further 7,043, for whom only the place of death is known, not their identities nor the date of their death. According to Laurens, the largest part of Palestinian casualties consisted of non-combatants and corresponds to the successful operations of the Israelis.",
#   'id': 2},
#  {'context': 'As Thomas Hall (2000) notes, "The Sung Empire in particular nearly underwent a transformation to capitalism in the tenth century C.E. But the only states to be controlled by capitalists before the European transformation in the seventeenth century were semiperipheral capitalist city-states such as the Phoenician cities, Venice, Genoa, and Malacca. These operated in the interstices between the tributary states and empires, and though they were agents of commodification, they existed within larger systems in which the logic of state-based coercion remained dominant. The first capitalist nation-state was the Dutch Republic in the seventeenth century. This coming to state power by capitalists in an emerging core region signaled the triumph of regional capitalism in the European subsystem." In Werner Sombart\'s words, "In all probability the United Provinces were the land in which the capitalist spirit for the first time attained its fullest maturity; where this maturity related to all its aspects, which were equally developed; and where this development had never been done comprehensive before. Moreover, in the Netherlands an entire people became imbued with the capitalist spirit; so much so, that in the 17th century Holland was universally regarded as the land of capitalism par exellence; it was envied by all other nations, who put forth their keenest endeavours in their desire to emulate it; it was the high school of every art of the tradesman, and the well-watered garden wherein the middle-class virtues throve." Foundational thinkers for this approach include Adam Smith, Max Weber, Fernand Braudel, Henri Pirenne, and Paul Sweezy.',
#   'id': 3},
#  {'context': 'World War I (often abbreviated as WWI or WW1), also known as the First World War or the Great War, was a global war originating in Europe that lasted from 28 July 1914 to 11 November 1918. Contemporaneously described as "the war to end all wars", it led to the mobilisation of more than 70 million military personnel, including 60 million Europeans, making it one of the largest wars in history. It is also one of the deadliest conflicts in history, with an estimated nine million combatants and seven million civilian deaths as a direct result of the war, while resulting genocides and the 1918 influenza pandemic caused another 50 to 100 million deaths worldwide.',
#   'id': 4}]

# %% [markdown]
# # BART method

# %% [markdown]
# **Set up BART**

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "True"

bart_tokenizer = AutoTokenizer.from_pretrained("Andyrasika/bart_tech_keywords")
bart_model = AutoModelForSeq2SeqLM.from_pretrained("Andyrasika/bart_tech_keywords")

keyword_extractor = pipeline("text2text-generation", 
                             model=bart_model, 
                             tokenizer=bart_tokenizer,
                             max_new_tokens=50)
                            #  device=0) # GPU

# %% [markdown]
# **Handle long context**

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=4000,
    chunk_overlap=20,
    length_function=len,
    is_separator_regex=False,
)

# %% [markdown]
# **Avoid IndexError when input exceeds model limits(1024)**

# %%
keywords = []
for i in tqdm(range(len(data))):
    text = data[i]['context']
    num_tokens = len(bart_tokenizer.encode(text))
    if num_tokens >= 1024:
        split_texts = text_splitter.create_documents([data[i]['context']])
        sub_keys = []
        for t in split_texts:
            sub_keys.append(keyword_extractor(t.page_content)[0]['generated_text'])
        keywords.append(sub_keys)
    else:
        keywords.append(keyword_extractor(text)[0]['generated_text'])
# Out:
#   0%|          | 0/13932 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1123: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (1374 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# **Save results**

# %%
def flatten_nested_list(nested_list):
    result = []
    for item in nested_list:
        if isinstance(item, list):
            flattened_item = ', '.join(item)
            result.append(flattened_item)
        else:
            result.append(item)
    return result

# %%
keywords[6159:6162]
# Out:
# ['United States of America, Federal Republic',
#  ['Dram, National Currency, Central Bank of Armenia, ISO, UNICODE',
#   'Armenia, Banknotes, Coins, Security Printing',
#   "Collector Coins, Banknotes, Coins, Central Bank of Armenia, Noah's Ark"],
#  'Buenos Aires, Argentina, Río de la Plata']

# %%
flattened_list = flatten_nested_list(keywords)
flattened_list[6159:6162]
# Out:
# ['United States of America, Federal Republic',
#  "Dram, National Currency, Central Bank of Armenia, ISO, UNICODE, Armenia, Banknotes, Coins, Security Printing, Collector Coins, Banknotes, Coins, Central Bank of Armenia, Noah's Ark",
#  'Buenos Aires, Argentina, Río de la Plata']

# %%
len(flattened_list), len(keywords)
# Out:
# (13932, 13932)

# %%
strip_key_words = [line.strip() for line in flattened_list]
ids = [item['id'] for item in data]

assert len(ids) == len(strip_key_words)

print(f"Total num: {len(strip_key_words)}")
# Out:
# Total num: 13932

# %%
documents = [
    {"context_id": id, "keywords": [k.strip() for k in kw.split(',')]} 
    for id, kw in zip(ids, strip_key_words)
]

json_data = json.dumps(documents, indent=4)
# print(json_data)

# %%
with open('./data/BART_Keywords.json', 'w') as f:
    f.write(json_data)

# %% [markdown]
# # BERT method

# %% [markdown]
# **Set up BART**

# %%
tokenizer = AutoTokenizer.from_pretrained("yanekyuk/bert-uncased-keyword-extractor")
model = AutoModelForTokenClassification.from_pretrained("yanekyuk/bert-uncased-keyword-extractor")
kw_extractor = pipeline("token-classification", 
                        model="yanekyuk/bert-uncased-keyword-extractor",
                        tokenizer = tokenizer)

# %%
def segment_text(id, text, max_length=512, step_size=256):
    """
    After exceeding the maximum bert input limit, use the slide window to truncate to size=256
    """
    segments = []
    start = 0
    while start < len(text):
        if start + max_length > len(text):
            segment = text[start:]
            segments.append(segment)
            id.append(id[-1]+1)
            break
        
        segment = text[start:start+max_length]
        segments.append(segment)
        id.append(id[-1])
        start += step_size

    return segments

def preprocess(data):
    preprocessed_data = []
    id_context=[0]
    for item in data:
        context = item['context']
        context = re.sub(r'\s+', ' ', context).strip()
        segmented_contexts = segment_text(id_context, context)
        preprocessed_data.extend(segmented_contexts) 
    return preprocessed_data, id_context

def KeyWords_generator(outputs, text):
    keywords = []
    current_keyword = None
    current_start = None
    current_end = None

    for item in outputs:
        if item['entity'] == 'B-KEY':
            if current_keyword:
                keyword = text[current_start:current_end]
                if keyword.count(' ') < 4:
                    keywords.append(keyword) 
                current_keyword = None
            current_start = item['start']
            current_keyword = item['word']
        elif item['entity'] == 'I-KEY' and current_keyword:
            current_keyword = item['word']
        current_end = item['end']

    if current_keyword:
        keyword = text[current_start:current_end]
        if keyword.count(' ') < 4:
            keywords.append(keyword)

    return keywords

# %%
texts, id_context = preprocess(data)
FILE_WRITE = "./data/BERT_Keywords.json"

def main():
    doc_kw = []
    with open(FILE_WRITE, 'w') as file:
        keywords = KeyWords_generator(kw_extractor(texts[0]), texts[0])
        for i in tqdm(range(1, len(texts))):
            if id_context[i] != id_context[i-1]:
                kw_list = list(set(keywords))
                print(kw_list)
                data_dic = {
                    'context': data[id_context[i] - 1],
                    'keywords': kw_list
                }
                # file.write(f"Text {id_context[i]-1} Keywords: {', '.join(list(set(keywords)))}\n\n")
                doc_kw.append(data_dic)
                keywords = KeyWords_generator(kw_extractor(texts[i]), texts[i])
            else:
                keywords += KeyWords_generator(kw_extractor(texts[i]), texts[i])
        json.dump(doc_kw, file, ensure_ascii=False, indent=4)
    
       
main()
# Out:
#   0%|          | 0/30042 [00:00<?, ?it/s]
# ['anonymous', 'editor-in-chief', 'Julian Assange', 'WikiLeaks', 'Sunshine Press', 'Kristinn Hrafnsson', 'Iceland', 'Internet']
#   0%|          | 3/30042 [00:01<3:34:17,  2.34it/s]
# ['Soviet Union', 'Hiroshima', 'Nagasaki', 'Japan', 'war crimes', 'unconditional surrender', 'Adolf Hitler', 'atomic bombs', 'Potsdam Declaration', 'Western Allies', 'Soviet', 'United States']
#   0%|          | 6/30042 [00:02<3:17:44,  2.53it/s]
# ['marriage equality', 'Loving v. Virginia', 'Due Process Clause', 'gay marriage', 'separate marriage', 'Same-sex marriage']
#   0%|          | 6/30042 [00:03<4:17:08,  1.95it/s]

# %% [markdown]
# # Load output keywords again

# %%
bart_file_path = './data/BART_Keywords.json'
bert_file_path = './data/BERT_Keywords.json'

# %% [markdown]
# **BART**

# %%
with open(bart_file_path, 'r') as f:
    data_bart = json.load(f)

print(f"Total num: {len(data_bart)}")
# Out:
# Total num: 13932

# %% [markdown]
# **BERT**

# %%
with open(bert_file_path, 'r') as f:
    data_bert = json.load(f)

print(f"Total num: {len(data_bert)}")
# Out:
# Total num: 13932

# %% [markdown]
# # BART X BERT

# %%
merged_data = {}
order = []

# Bart -> merged_data
for item in data_bart:
    context_id = item['context_id']
    merged_data[context_id] = item['keywords']
    order.append(context_id)

# Bert -> merged_data
for item in data_bert:
    context_id = item['context_id']
    if context_id not in merged_data:
        merged_data[context_id] = item['keywords']
        order.append(context_id)
    else:
        # merge the keywords and drop duplicates.
        merged_data[context_id].extend([kw for kw in item['keywords'] if kw not in merged_data[context_id]])

merged_list = [{'context_id': key, 'keywords': merged_data[key]} for key in order]

print(f"Total num: {len(merged_list)}")
merged_list
# Out:
# Total num: 13932
# [{'context_id': 0,
#   'keywords': ['WikiLeaks',
#    'News Leaks',
#    'Sunshine Press',
#    'Kristinn Hrafnsson',
#    'Julian Assange',
#    'Iceland',
#    'editor-in-chief',
#    'anonymous',
#    'Internet']},
#  {'context_id': 1,
#   'keywords': ['World War II',
#    'Europe',
#    'Japan',
#    'Soviet Union',
#    'War Crimes Trials',
#    'atomic bombs',
#    'United States',
#    'Germans',
#    'Western Allies',
#    'Hiroshima',
#    'Potsdam Declaration']},
#  {'context_id': 2,
#   'keywords': ['Arab War',
#    'Casualties',
#    'Henry Laurens',
#    'Egypt',
#    'Jordan',
#    'Aref al-Aref',
#    'Palestinians']},
#  {'context_id': 3,
#   'keywords': ['Capitalism',
#    'European Transformation',
#    'Adam Smith',
#    'Max Weber',
#    'Fernand Braudel',
#    'Henri Pirenne',
#    'Paul Sweezy',
#    'Venice',
#    'nation',
#    'capitalism',
#    'Malacca',
#    'Werner Sombart',
#    'Genoa',
#    'United Provinces',
#    'Holland',
#    'Dutch Republic',
#    'Netherlands']},
#  {'context_id': 4,
#   'keywords': ['World War I',
#    'WWI',
#    'Great War',
#    'Genocides',
#    'Influenza Pandemic',
#    'genocide',
#    '1918 influenza pandemic',
#    'World War']},
#  {'context_id': 5,
#   'keywords': ['Evolutionary Ideas',
#    'Jean-Baptiste Lamarck',
#    'Charles Darwin',
#    'Natural Selection',
#    'natural selection',
#    'George Combe',
#    'species',
#    'The Constitution of Man',
#    'Georges Cuvier',
#    'transmutation of species']},
#  {'context_id': 6,
#   'keywords': ['Darwinian Evolution',
#    'Natural Selection',
#    'Mendelian Genetic Variability',
#    'Adaptation',
#    'natural selection',
#    'modern synthesis',
#    'evolution',
#    'genetics',
#    'orthogenesis',
#    'Alfred Russel Wallace',
#    'mutationism',
#    'Evolution',
#    'Charles Darwin',
#    'Mendelian genetic variation',
#    'adaptive evolution',
#    'Darwinian evolution']},
#  {'context_id': 7,
#   'keywords': ['Republican Party',
#    'Conservatism',
#    'Progressive Party',
#    'New Deal Democrats',
#    'Third Party System',
#    'New Deal',
#    'Fourth Party',
#    'Theodore Roosevelt',
#    'Democratic Party',
#    'Abraham Lincoln',
#    'Barry Goldwater',
#    'classical liberalism']},
#  {'context_id': 8,
#   'keywords': ['Jimmy Donal Wales',
#    'Wikipedia',
#    'Wikia',
#    'Jimbo',
#    'entrepreneur',
#    'Internet']},
#  {'context_id': 9,
#   'keywords': ['Islam',
#    'History',
#    'Muhammad',
#    'Christianity',
#    'Jesus',
#    'Islamic civilization',
#    'Mecca',
#    'Medina',
#    'Muslims']},
#  {'context_id': 10,
#   'keywords': ['Great Salt Lake',
#    'Utah',
#    'Salt Water Lake',
#    'Terminal Lake',
#    'Great Lakes',
#    'salt water lake',
#    'Western Hemisphere']},
#  {'context_id': 11,
#   'keywords': ['Wikipedia',
#    'Jimmy Wales',
#    'Larry Sanger',
#    'English Wikipedia',
#    'wiki',
#    'portmanteau']},
#  {'context_id': 12,
#   'keywords': ['Arnold Schwarzenegger',
#    'Republican Presidential Candidate',
#    'John McCain',
#    'pro-choice',
#    'same-sex marriage',
#    'George W. Bush',
#    'Bill Clinton',
#    'socially moderate',
#    'George H.W. Bush',
#    'Ohio',
#    'embryonic stem cell research',
#    'Schwarzenegger',
#    'Ronald Reagan']},
#  {'context_id': 13,
#   'keywords': ['On the Origin of Species',
#    'Natural Selection',
#    'Evolutionary Biology',
#    'natural selection',
#    'scientific',
#    'Charles Darwin',
#    'Species',
#    'evolutionary biology']},
#  {'context_id': 14, 'keywords': ['Athens', 'Greece', 'Attica']},
#  {'context_id': 15,
#   'keywords': ['Content Theory',
#    'Human Motivation',
#    'Abraham Maslow',
#    "Herzberg's Two-Factor Theory",
#    "Abraham Maslow's hierarchy of",
#    'motivation',
#    'two-factor theory',
#    'Herzberg']},
#  {'context_id': 16,
#   'keywords': ['Feminist Sex Wars',
#    'Porn Feminist',
#    'Sex Positive Feminist',
#    'sadomasochism',
#    'pornography',
#    'feminist',
#    'trans women',
#    'erotica',
#    'lesbian community']},
#  {'context_id': 17,
#   'keywords': ['Raja Harishchandra',
#    'Indian Silent Film',
#    'Dadasaheb Phalke',
#    'Dattatraya Damodar Dabke',
#    'Ramayana',
#    'Bhalchandra Phalke',
#    'Anna Salunke',
#    'silent film',
#    'Mahabharata',
#    'Harishchandra']},
#  {'context_id': 18,
#   'keywords': ['Charles Darwin',
#    'Alfred Russel Wallace',
#    'Natural Selection',
#    'Mendelian Genetics',
#    'Population Genetics',
#    'natural selection',
#    'Mendelian genetics',
#    'Ronald Fisher',
#    'biogeography',
#    'embryology',
#    'orthogenesis',
#    'rthogenesis',
#    'saltationism',
#    'J. B. S. Haldane',
#    'Sewall Wright',
#    'modern',
#    'animal husbandry',
#    'Lamarckism',
#    'population genetics']},
#  {'context_id': 19,
#   'keywords': ['Hughes',
#    'Literature',
#    'Galbraith Prize',
#    'Galbraith prize',
#    'Crow']},
#  {'context_id': 20,
#   'keywords': ['iPhone 3G',
#    'iPhone 3GS',
#    'iPhone 4',
#    'iPhone 5',
#    'iPhone',
#    'Verizon',
#    'Sprint',
#    'iPhone 3']},
#  {'context_id': 21,
#   'keywords': ['NBC',
#    'Coast-to-Coast Radio Network',
#    'NBC',
#    'CBS',
#    'Mutual Broadcasting System']},
#  {'context_id': 22,
#   'keywords': ['Keynes',
#    'Economic Consequences',
#    'Peace Treaty',
#    'economist']},
#  {'context_id': 23,
#   'keywords': ['Republican Party',
#    'Grand Old Party',
#    'Kansas–Nebraska Act',
#    'Missouri Compromise',
#    'Free Soil',
#    'economic conservatism',
#    'Democratic Party']},
#  {'context_id': 24,
#   'keywords': ['Al-Qaeda',
#    'Bin Laden',
#    'Abdullah Azzam',
#    'Database',
#    'Osama bin Laden',
#    'Islamist',
#    'Sunni',
#    'Soviet invasion of Afghanistan']},
#  {'context_id': 25,
#   'keywords': ['Indian Navy',
#    'Operation Trident',
#    'Operation Python',
#    'East Pakistan',
#    'Pakistan',
#    'India',
#    'Western front']},
#  {'context_id': 26, 'keywords': ['Moscow', 'Russia']},
#  {'context_id': 27,
#   'keywords': ['Roman Empire',
#    'Byzantine Empire',
#    'Greek East',
#    'Latin West',
#    'Orthodox Christianity',
#    'Byzantium',
#    'Latin',
#    'Empire',
#    'ancient Rome',
#    'Theodosius I',
#    'Constantine I',
#    'Heraclius',
#    'Roman state',
#    'Constantinople',
#    'empire']},
#  {'context_id': 28,
#   'keywords': ['India',
#    'History',
#    'Indo-Aryan Civilization',
#    'Vedic Civilisation',
#    'Jainism',
#    'Buddhism',
#    'Indian subcontinent',
#    'Republic of India',
#    'Indian',
#    'British India',
#    'Hinduism',
#    'Indus Valley Civilisation']},
#  {'context_id': 29,
#   'keywords': ['Origen of Alexandria',
#    'Alexandrian',
#    'Christian Theology',
#    'Apologetics',
#    'Homiletics',
#    'biblical exegesis',
#    'apologetics',
#    'Alexandria',
#    'asceticism',
#    'biblical hermeneutics',
#    'textual criticism',
#    'theologian',
#    'theology']},
#  {'context_id': 30,
#   'keywords': ['Linux kernel',
#    'Operating System',
#    'ARM',
#    'iPAQ',
#    'IBM',
#    'ELKS',
#    'µClinux',
#    'operating system',
#    'Intel 80286',
#    'kernel',
#    'memory management unit',
#    'mainframe',
#    'PowerPC',
#    'kernel fork',
#    'Intel 8086']},
#  {'context_id': 31, 'keywords': ['Gedun Drupa', 'Dalai Lama', '1st']},
#  {'context_id': 32,
#   'keywords': ['Damascus',
#    'Umayyad Caliphate',
#    'Baghdad',
#    'Ayyubid',
#    'Mamluk',
#    'Abbasid dynasty',
#    'second',
#    'Abbasid era']},
#  {'context_id': 33,
#   'keywords': ['Bangladesh', 'Pornography Control Act', 'pornography']},
#  {'context_id': 34,
#   'keywords': ['Detroit',
#    'Michigan',
#    'Metropolitan Area',
#    'Art',
#    'Architecture',
#    'Design',
#    'United States–Canada border',
#    'United States',
#    'Metro Detroit',
#    'metropolitan area',
#    'Chicago metropolitan area',
#    'Wayne']},
#  {'context_id': 35,
#   'keywords': ['Television',
#    'Alexandre Perskyi',
#    'French télévision',
#    'flat-screen TV',
#    'telly',
#    'cathode ray tube',
#    'small screen',
#    'big screen',
#    'televista',
#    'telephote',
#    'television',
#    'télévision']},
#  {'context_id': 36,
#   'keywords': ['Burmese Language',
#    'Sino-Tibetan Language',
#    'Bamar',
#    'Myanmar Language',
#    'Bamar people',
#    'Myanmar',
#    'official language',
#    'Sino-Tibetan language',
#    'Myanmar language',
#    'Constitution of Myanmar',
#    'Burma',
#    'first language',
#    'Burmese language']},
#  {'context_id': 37,
#   'keywords': ['Zero-point energy',
#    'Zero-point Energy',
#    'Aristotle',
#    'Otto von Guericke',
#    'earth',
#    'vacuum pump',
#    'vacuum',
#    'energy']},
#  {'context_id': 38,
#   'keywords': ['East Pakistan',
#    'Pakistan',
#    'Ayub Khan',
#    'Yahya Khan',
#    'Bangladesh Liberation War',
#    '1971 Bangladesh Genocide',
#    'Iskandar Mirza',
#    'India',
#    'universal suffrage',
#    'One Unit scheme',
#    'Yahya Kha',
#    'East Bengal',
#    'Awami League',
#    'Mujibur Rahman',
#    'democracy',
#    'martial law',
#    'Pakistan Peoples Party',
#    '1971 Bangladesh genocide',
#    'Sheikh',
#    'civil',
#    'H. S. Suhrawardy',
#    'Islamic republic',
#    'Constitution of Pakistan of',
#    'Mohammad Ali of Bogra']},
#  {'context_id': 39,
#   'keywords': ['Abu Bakr',
#    'Sahabi',
#    'Caliph',
#    'Sunni Islam',
#    'Muhammad',
#    "Muhammad's father-in-law through Aisha",
#    'sahabi']},
#  {'context_id': 40,
#   'keywords': ['Islamic Law',
#    'Hadith',
#    'Hanafi',
#    'Maliki',
#    'Shafiʿi',
#    'Hanbali Legal Schools',
#    'Muhammad',
#    'Abu Hanifah',
#    'jurist',
#    'Islamic prophet',
#    'Islamic jurisprudence ("fiqh',
#    'Islamic',
#    'sunnah',
#    'Ahmad ibn Hanbal',
#    'hadith',
#    'Al-Shafi‘i',
#    'Sunni',
#    'Malik ibn Anas',
#    'jurisprudence']},
#  {'context_id': 41,
#   'keywords': ['Romania',
#    'Latin Empire',
#    'Constantinople',
#    'Crusader State',
#    'Eastern Roman (Byzantine) Empire',
#    'Fourth Crusade',
#    'Eastern Orthodox',
#    'Crusader state',
#    'historiography',
#    'Byzantine',
#    'Empire of Romania',
#    'Byzantine Empire',
#    'Latin Empire of',
#    'emperor']},
#  {'context_id': 42,
#   'keywords': ['Linux',
#    'Linux kernel',
#    'Free Software',
#    'Open Source',
#    'operating system',
#    'Linus Torvalds',
#    'operating',
#    'kernel',
#    'Linux distribution',
#    'software',
#    'open-source']},
#  {'context_id': 43,
#   'keywords': ['Apollo 1',
#    'AS-204',
#    'Apollo',
#    'Apollo Command',
#    'Service Module',
#    'Launch Rehearse Test',
#    'United States',
#    'Apollo program',
#    'Moon',
#    'Roger B. Chaffee',
#    'command module',
#    'NASA',
#    'Command']},
#  {'context_id': 44,
#   'keywords': ['Islamic State',
#    'Caliphate',
#    'Ottoman Empire',
#    'Muhammad',
#    'Muslim',
#    'Islamic state',
#    'caliphate',
#    'history',
#    'Islam',
#    'Islamic prophet',
#    'Abbasid Caliphate',
#    'Ottoman Caliphate',
#    'caliph',
#    'Rashidun Caliphate',
#    'Umayyad Caliphate']},
#  {'context_id': 45,
#   'keywords': ['Universal History',
#    'Western Tradition',
#    'Axial Age',
#    'Classical antiquity',
#    'Arabic',
#    'Asian Histiographies',
#    'Universal history',
#    'prehistory',
#    'Karl Jaspers',
#    'history',
#    'planetary history',
#    'classical antiquity']},
#  {'context_id': 46,
#   'keywords': ['USA Network',
#    'NBCUniversal Cable Entertainment Group',
#    'Comcast',
#    'Sports Network',
#    'TBS',
#    'TNT',
#    'FX',
#    'NBCUniversal',
#    'satellite television',
#    'network',
#    'cable',
#    'subsidiary']},
#  {'context_id': 47,
#   'keywords': ['Trevor Leslie Goddard',
#    'Test Cricketer',
#    'all-rounder',
#    'captain']},
#  {'context_id': 48,
#   'keywords': ['Postal Service',
#    'America',
#    'Patent',
#    'Andrew Hamilton',
#    'Andrew Neale',
#    'Massachusetts',
#    'postmaster',
#    'Virginia',
#    'New York City',
#    'New Jersey',
#    'pacquet']},
#  {'context_id': 49,
#   'keywords': ['Alivardi Khan',
#    'Nawab of Bengal',
#    'Battle of Burdwan',
#    'Maratha Empire',
#    'Nawab',
#    'Nasiri Dynasty']},
#  {'context_id': 50,
#   'keywords': ['Russian History',
#    'East Slavs',
#    'Finno-Ugric',
#    'Byzantine Empire',
#    'Mongol invasions',
#    "Kievan Rus'",
#    'Russia',
#    'Finno-Ugric peoples']},
#  {'context_id': 51,
#   'keywords': ['Jonathan David Good',
#    'WWE',
#    'Dean Ambrose',
#    'professional wrestler',
#    'ring name']},
#  {'context_id': 52,
#   'keywords': ['Personal Computer',
#    'IBM Personal Computer',
#    'Microprocessor',
#    'microcomput',
#    'mainframe computer',
#    'microprocessor',
#    'time-sharing',
#    'microcomputer revolution',
#    'personal computer']},
#  {'context_id': 53,
#   'keywords': ['Photosynthesis',
#    'Charles Reid Barnes',
#    'Anoxygenic bacteria',
#    'Photophosphorylation',
#    'chlorophyll',
#    'photosynthetic',
#    'photosynthesis',
#    'photophosphorylation',
#    'bacteria',
#    'carbonic acid']},
#  {'context_id': 54,
#   'keywords': ['INA',
#    'Burma',
#    'Japanese Army',
#    'British Army',
#    'Delhi Trials',
#    'British army',
#    'Delhi',
#    'Captain',
#    'time',
#    'Imphal']},
#  {'context_id': 55,
#   'keywords': ['Ritchie',
#    'First Class Cricket',
#    'Queensland',
#    'New Zealand',
#    'India',
#    'century']},
#  {'context_id': 56,
#   'keywords': ['Barack Obama',
#    'Executive Orders',
#    'Presidential Memoranda',
#    'Guantanamo Bay',
#    'Iraq',
#    'Mexico City Policy',
#    'Mexico City',
#    'George W. Bush',
#    'Guantanamo',
#    'executive orders',
#    'abortion',
#    'Guantanamo Bay detention camp',
#    'Ronald Reagan']},
#  {'context_id': 57,
#   'keywords': ['Swallowtail Bird',
#    'freshwater lakes',
#    'migratory',
#    'Europe',
#    'Asia',
#    'breeding',
#    'bird',
#    'New Guinea']},
#  {'context_id': 58,
#   'keywords': ['WAVPM',
#    'Feminists Fighting Pornography',
#    'Antipornography Civil Rights Ordinance',
#    'San Francisco',
#    'New York',
#    'United States',
#    'Andrea Dworkin',
#    'porn industry',
#    'Women Against Pornography',
#    'Page Mellish',
#    'anti-pornography']},
#  {'context_id': 59,
#   'keywords': ['Z Force',
#    'Tura Brigade',
#    'Bangladesh Forces',
#    'Liberation War',
#    '1971',
#    'Battalion',
#    'military brigade',
#    'Liberation War of Bangladesh',
#    'Major Ziaur Rahman',
#    'brigade',
#    'Bangladesh',
#    'East Bengal']},
#  {'context_id': 60,
#   'keywords': ['Michael Madhusudan Dutt (1824–1873) Essayist',
#    'Essayists',
#    'Essays',
#    'Epics',
#    'Sonnets',
#    'Ramayana',
#    'Ravana',
#    'blank verse',
#    'Hindu Puranas',
#    'Versailles,',
#    'Braj',
#    'Meghnad Badh Kabya',
#    'Krishnakumari',
#    'sonnets',
#    'adh Kabya',
#    'Sharmishtha',
#    'Meghnad',
#    'Tilottama Sambhab Kabya',
#    'Versailles',
#    'Padmavati',
#    'the Lanka War',
#    'Tilottama',
#    'Bengali',
#    'Hindu',
#    'Lanka War',
#    'Michael Madhusudan Dutt']},
#  {'context_id': 61,
#   'keywords': ['Italian Renaissance',
#    'Renaissance History',
#    'Renaissance Humanists',
#    'Modern',
#    'history',
#    'Italy',
#    'renaissance',
#    'Dark Ages',
#    'Giorgio Vasari',
#    'Jules Michelet',
#    'Jacob Burckhardt',
#    'Trecento',
#    'Renaissance',
#    'classical antiquity']},
#  {'context_id': 62,
#   'keywords': ['LGBT Rights',
#    'U.S. Supreme Court',
#    'Obergefell v. Hodges',
#    'Lawrence v. Texas',
#    'United',
#    'transgender',
#    'Lesbian',
#    'bisexual']},
#  {'context_id': 63,
#   'keywords': ['Larry Sanger',
#    'Citizendium',
#    'Encyclopedia Wiki',
#    'wiki',
#    'Wikipedia',
#    'encyclopedia']},
#  {'context_id': 64,
#   'keywords': ['Wright Brothers',
#    'Aviation Pioneers',
#    'Aircraft Controls',
#    'aviation',
#    'airplane',
#    'Kitty Hawk, North Carolina',
#    'aircraft',
#    'Wright brothers']},
#  {'context_id': 65,
#   'keywords': ['German Language',
#    'Berlin',
#    'European Union',
#    'West Germanic language',
#    'Indo-European language family',
#    'European Commission']},
#  {'context_id': 66,
#   'keywords': ['Al-Mansur',
#    'Abbasid Dynasty',
#    'Humeima',
#    'Muhammad',
#    'Dhu al-Hijjah',
#    'Rawd al-Qirtas',
#    'Abbas',
#    'Jordan',
#    'Hejaz',
#    'Abbas ibn Abd al-Muttalib']},
#  {'context_id': 67,
#   'keywords': ['Albert R. Broccoli',
#    'Harry Saltzman',
#    'Eon Productions',
#    'James Bond',
#    'Danjaq',
#    'Sound Editing',
#    'Visual Effects',
#    'For Your Eyes Only',
#    'films',
#    'United Artists',
#    'inflation',
#    'Karen Baker Landers',
#    'Sheena Easton',
#    'Carly Simon',
#    'Terence Young',
#    'Academy Awards',
#    'John Stears',
#    'Dr. No',
#    'Marvel Cinematic Universe',
#    'Goldfinger',
#    '85th Awards',
#    'Sam Smith',
#    'Live and Let Die',
#    'Star Wars',
#    'Paul Epworth',
#    'Per Hallberg',
#    'holding company',
#    'Spectre',
#    'Wizarding World',
#    'Adele',
#    'Skyfall',
#    'Paul McCartney',
#    'Jimmy Napes',
#    'Thunderball',
#    'Nobody Does It Better']},
#  {'context_id': 68,
#   'keywords': ['Constantinople',
#    'Roman Emperor Constantine I',
#    'Byzantine Empire',
#    'Megara',
#    'Chalcedon',
#    'Roman Emperor',
#    'Byzantium',
#    "Pliny's Natural Histories",
#    'Constantine I',
#    'Bosphorus']},
#  {'context_id': 69,
#   'keywords': ['Hinduism',
#    'Divinities',
#    'Yajurveda',
#    'Hindu culture',
#    'Brahman']},
#  {'context_id': 70,
#   'keywords': ['Antifeminism',
#    'Feminism',
#    'Equal Rights Amendment',
#    'antifeminism',
#    'feminism',
#    "women's suffrage"]},
#  {'context_id': 71, 'keywords': ['Sura', 'Quran', 'sura']},
#  {'context_id': 72,
#   'keywords': ['DHS 2014', 'Population Structure', 'population']},
#  {'context_id': 73,
#   'keywords': ['Company Rule',
#    'India',
#    'Robert Clive',
#    'Warren Hastings',
#    'Peshwa',
#    'Indian',
#    'Battle of Plassey',
#    'Nawab',
#    'Bihar',
#    'British East India Company',
#    'diwani',
#    'dominion',
#    'Bengal']},
#  {'context_id': 74,
#   'keywords': ['Edison',
#    'Cinématographe',
#    'Kinetoscope',
#    'Cinematograph',
#    'Celluloid Film',
#    'Louis Lumière',
#    'cinematograph',
#    '35 mm film',
#    'celluloid film',
#    'celluloid',
#    'peepshow',
#    'motion picture',
#    'kinetoscope']},
#  {'context_id': 75,
#   'keywords': ['Ukrainian President',
#    'Electoral Process',
#    'Ukrainian president',
#    'President']},
#  {'context_id': 76,
#   'keywords': ['Sheikh Mujibur Rahman',
#    'Bangladesh',
#    'Awami League',
#    "People's Republic",
#    'Pakistan',
#    'Mujibur Rahman',
#    'East Pakistan',
#    'Mu',
#    'Bangabandhu',
#    'Sheikh',
#    'Bangladesh Liberation Movement',
#    'Sheikh Hasina']},
#  {'context_id': 77,
#   'keywords': ['Hells',
#    'Yama',
#    'Yamadutas',
#    'Svarga',
#    'Naraka',
#    'hell',
#    'heaven']},
#  {'context_id': 78,
#   'keywords': ['Pregnancy Diet',
#    'Thai Medicine',
#    'Rice',
#    'Vegetables',
#    'Jackfruit',
#    'Thai medicine',
#    'pregnancy',
#    'Herbal tea',
#    'jackfruit']},
#  {'context_id': 79,
#   'keywords': ['Sura',
#    'Meccan',
#    'Medinan',
#    'Quran',
#    'Muhammad',
#    'Mecca',
#    'Medina',
#    'Bismillah']},
#  {'context_id': 80, 'keywords': ['Windows 10', 'Redstone 5']},
#  {'context_id': 81,
#   'keywords': ['Edward Teller',
#    'Manhattan Project',
#    'Fusion Weapon',
#    'Hydrogen Bomb',
#    'nuclear fusion',
#    'Robert Oppenheimer',
#    'hydrogen bomb',
#    'nuclear fission',
#    'atomic bomb',
#    'atomic warfare',
#    'Enrico Fermi',
#    'fission weapon',
#    'University of California, Berkeley']},
#  {'context_id': 82, 'keywords': ['Gay Sex', 'India', 'Supreme Court']},
#  {'context_id': 83,
#   'keywords': ['Voter Turnout',
#    '2016 Election',
#    'Census Bureau',
#    'Michael McDonald',
#    'voting eligible population',
#    'University of Florida']},
#  {'context_id': 84,
#   'keywords': ['London',
#    'City of London',
#    'Westminster',
#    'North Sea',
#    'Londinium',
#    'River Thames',
#    'United Kingdom',
#    'Greater London',
#    'London Assembly',
#    'Square',
#    'estuary',
#    'Mayor of London',
#    'England',
#    'Inner London borough']},
#  {'context_id': 85,
#   'keywords': ['Keynes',
#    'Economic Journal',
#    'Royal Commission',
#    'Indian Currency',
#    'Finance',
#    'John Neville Keynes',
#    'Royal Commission on Indian',
#    'J M Keynes',
#    'economic theory']},
#  {'context_id': 86,
#   'keywords': ['Wundt',
#    'Physiological Psychology',
#    'Leipzig',
#    'Experimental Psychology',
#    'Psychology',
#    'William James',
#    'Frank Angell',
#    'James McKeen Cattell',
#    'experimental psychology',
#    'G. Stanley Hall',
#    'Edward Bradford Titchener']},
#  {'context_id': 87, 'keywords': ['Ali', 'Muawiyah', 'Caliphate', 'caliphate']},
#  {'context_id': 88,
#   'keywords': ['Sacramento',
#    'California',
#    'State Capital',
#    'American River',
#    'Sacramento Valley',
#    'Sacramento metropolitan area',
#    'Supreme Court of California',
#    'Sacramento River',
#    'Sacramento County']},
#  {'context_id': 89,
#   'keywords': ['Egyptian Language',
#    'Afro-Asiatic Languages',
#    'Sumerian',
#    'Middle Egyptian',
#    'Egyptian language',
#    'ancient Egypt',
#    'Old Kingdom of Egypt',
#    'Afro-Asiatic languages']},
#  {'context_id': 90,
#   'keywords': ['Kite', 'Aviation', 'China', 'Mozi', 'kite', 'Gongshu']},
#  {'context_id': 91,
#   'keywords': ['Fanfou',
#    'Chinese Microblogging',
#    'Twitter Clone',
#    'Fan',
#    'Twitter',
#    'China',
#    'microblogging']},
#  {'context_id': 92,
#   'keywords': ['Middle English',
#    'Marriage',
#    'Old French',
#    'Latin',
#    'Latin "mātrimōnium',
#    'maria',
#    'matrimony']},
#  {'context_id': 93,
#   'keywords': ['Latin',
#    'Latin',
#    'Greek',
#    'French',
#    'Romance Languages',
#    'Roman Republic',
#    'Vulgar Latin',
#    'Rome',
#    'Italy',
#    'Ancient Greek',
#    'Latium',
#    'theology',
#    'western Roman Empire',
#    'Romance languages',
#    'English language']},
#  {'context_id': 94,
#   'keywords': ['Badasht',
#    'Seneca Falls Convention',
#    'Feminism',
#    'Frederick Douglass',
#    'Elizabeth Cady Stanton',
#    'Iran',
#    'time',
#    'Seneca']},
#  {'context_id': 95,
#   'keywords': ['Centennial Light',
#    'Shelby Electric Company',
#    'Livermore Fire Department',
#    'common light bulb',
#    'Dennis Bernal',
#    'Shelby, Ohio']},
#  {'context_id': 96,
#   'keywords': ['Atomic Nucleus',
#    'Neutron',
#    'James Chadwick',
#    'proton',
#    'atomic nucleus',
#    'elementary particle',
#    'neutron']},
#  {'context_id': 97,
#   'keywords': ['Myanmar',
#    '2014 Census',
#    'Population',
#    'Rakhine State',
#    'Kachin State',
#    'Kayin State',
#    'time']},
#  {'context_id': 98,
#   'keywords': ['Maratha invasions of Bengal',
#    'Bengal Subah',
#    'Carnatic Region',
#    'Nagpur',
#    'Nawab Alivardi Khan',
#    'Raghoji Bhonsle',
#    'Na',
#    'Marathas',
#    'Carnatic region',
#    'Maratha',
#    'Maratha Empire',
#    'Maratha invasions of',
#    'Nawab',
#    'Bihar',
#    'Orissa',
#    'Bengal',
#    'Nawab of Bengal',
#    'Battle of Trichinopoly']},
#  {'context_id': 99,
#   'keywords': ['Khalid bin Abdulaziz Al Saud',
#    'King of Saudi Arabia',
#    'Middle East',
#    'Saudi Arabia',
#    'King']},
#  {'context_id': 100,
#   'keywords': ["Sen began his high-school education at St Gregory's School",
#    'Dhaka',
#    'Patha Bhavana',
#    'Shantiniketan',
#    'Presidency College',
#    'Kolkata',
#    'Trinity College',
#    'Cambridge',
#    'Pure Economics',
#    'Trinity College, Cambridge',
#    'Presidency College, Kolkata',
#    'Mathematics',
#    'oral cancer',
#    'Majlis',
#    'University of Calcutta',
#    'time',
#    'Jadavpur University',
#    'Calcutta',
#    'new Economics']},
#  {'context_id': 101,
#   'keywords': ['Gangasagar Mela',
#    'South 24 Pargana',
#    'Sagar Dwip',
#    'Kapil Muni',
#    'ashram',
#    'Makar Sankranti',
#    'South 24 Pargana district',
#    'winter',
#    'Bay of Bengal',
#    'festival',
#    'pilgrims',
#    'Sagar Dwip islands',
#    'Gangasagar']},
#  {'context_id': 102,
#   'keywords': ['Nepal',
#    'Gorkha Earthquake',
#    'Mercalli Intensity VIII',
#    'Barpak',
#    'Gorkha',
#    'Mercalli',
#    '1934 Nepal–Bihar earthquake',
#    'ground motion',
#    'Gorkha District',
#    'time',
#    'April 2015 Nepal earthquake',
#    'Gorkha earthquake']},
#  {'context_id': 103,
#   'keywords': ['Bangladesh Genocide',
#    'Operation Searchlight',
#    'Pakistani Military',
#    'Islamist militias',
#    'Jamaat-e-Islami',
#    'Bengali Women',
#    'India',
#    'West Pakistan',
#    'Bangladesh war for independence',
#    'time',
#    'Bihar',
#    'BBC News',
#    'genocide',
#    'Bangladesh',
#    'self-determination']},
#  {'context_id': 104,
#   'keywords': ['Akkadian Empire',
#    'Assyrians',
#    'Sumerians',
#    'Sargon the Great',
#    'Assyria',
#    'Mesopotamia',
#    'Akkad',
#    'Akkadian',
#    'Akka']},
#  {'context_id': 105,
#   'keywords': ['Nice',
#    'Alpes-Maritimes',
#    'French Riviera',
#    'Mediterranean Sea',
#    'Alps',
#    'France',
#    'Marseille',
#    'principality of Monaco',
#    'Mediterranean',
#    'metropolitan area',
#    "Provence-Alpes-Côte d'Azur"]},
#  {'context_id': 106,
#   'keywords': ['Sonam Gyatso',
#    'Dalai Lama',
#    'Altan Khan',
#    'Gendun Gyatso',
#    '3rd',
#    'Gyalwa Gendün Drup']},
#  {'context_id': 107,
#   'keywords': ['Greenhouse Effect',
#    'Claude Pouillet',
#    'John Tyndall',
#    'Svante Arrhenius',
#    'Carbon Dioxide',
#    'Joseph Fourier',
#    'Nils Gustaf Ekholm',
#    'global warming',
#    'greenhouse effect',
#    'carbon dioxide',
#    'greenhouse gases']},
#  {'context_id': 108,
#   'keywords': ['Roger Federer',
#    'Basel',
#    'Switzerland',
#    'Swiss German',
#    'Standard German',
#    'English',
#    'French',
#    'German',
#    'Italian',
#    'Swedish',
#    'ball boy',
#    'Swiss Indoors',
#    'Robert Federer',
#    'Bern',
#    'Birsfelden, Riehen',
#    'South Africa',
#    'Kempton Park, Gauteng']},
#  {'context_id': 109,
#   'keywords': ['Quran',
#    'Prophet Muhammad',
#    'Archangel Gabriel',
#    'Muhammad',
#    'Muslims']},
#  {'context_id': 110,
#   'keywords': ['Pregnancy',
#    'Fertilization',
#    'Implantation',
#    'implantation',
#    'implant',
#    'uterus',
#    'fertilization']},
#  {'context_id': 111,
#   'keywords': ['United States',
#    'United Kingdom',
#    'Turkey',
#    'Saudi Arabia',
#    'France',
#    'Israel',
#    'Human Rights Watch',
#    'Syrian Government',
#    'Bashar al-Assad']},
#  {'context_id': 112,
#   'keywords': ['Beautiful Names of Allah', 'Hadith', 'Allah', 'hadith']},
#  {'context_id': 113,
#   'keywords': ['Early Middle Ages',
#    'Early Medieval Period',
#    'Dark Ages',
#    'Middle Ages',
#    'history',
#    'Western Roman Empire',
#    'High Middle Ages',
#    'medieval',
#    'Late Antiquity',
#    'Roman Empire']},
#  {'context_id': 114,
#   'keywords': ['Septuagint',
#    'Hebrew Bible',
#    'Koine Greek',
#    'Latin Vulgate',
#    'Christian Church',
#    'Old Testament',
#    'Hellenistic Judaism',
#    'Talmud',
#    'Alexandria',
#    'Bible',
#    'Masoretic',
#    'deuterocanonical',
#    'Vulgate',
#    'Augustine of Hippo',
#    'Ptolemy II Philadelphus',
#    'Hebrew scriptures',
#    'septuagin',
#    'Christian church']},
#  {'context_id': 115,
#   'keywords': ['Abu Bakr',
#    'Rashidun Caliphate',
#    'Muhammad',
#    'Prophethood',
#    'Red Sea',
#    'Caliph',
#    'Islam',
#    'Muslims',
#    'Ridda',
#    'caliph',
#    'Dar Al Islam']},
#  {'context_id': 116,
#   'keywords': ['Virginia Beach',
#    'Virginia Beach',
#    'Chesapeake Bay',
#    'Hampton Roads',
#    'independent city',
#    'Commonwealth of Virginia',
#    'Norfolk',
#    'Virginia',
#    'metropolitan area',
#    'Suffolk',
#    'Atlantic Ocean']},
#  {'context_id': 117,
#   'keywords': ['Qutb',
#    'Health Issues',
#    'Religious Beliefs',
#    'Islam',
#    'Quran',
#    'Westernized']},
#  {'context_id': 118,
#   'keywords': ['Charles Robert Darwin',
#    'Natural Selection',
#    'Alfred Russel Wallace',
#    'natural selection',
#    'artificial selection',
#    'biologist',
#    'selective breeding']},
#  {'context_id': 119,
#   'keywords': ['Hinduism',
#    'Deities',
#    'Vaishnavism',
#    'Shaivism',
#    'Shaktism',
#    'Smartism',
#    'India',
#    'axiology',
#    'Brahman',
#    'Nepal',
#    'Sati',
#    'Hindus',
#    'Harihara',
#    'Ardhanārīshvara',
#    'Nirguna',
#    'polycentrism',
#    'Parvati',
#    'Yoga',
#    'theosophy',
#    'Sri',
#    'Shiva',
#    'Hindu',
#    'Saguna',
#    'Lakshmi',
#    'Brahma and Saraswati',
#    'Vishnu']},
#  {'context_id': 120,
#   'keywords': ['Heart Disease',
#    'Cardiovascular Diseases',
#    'Pericardium',
#    'Endocardium',
#    'Pacemaker',
#    'ECG',
#    'Ultrasound',
#    'heart',
#    'stroke',
#    'Fish',
#    'ultrasound',
#    'stethoscope',
#    'endocardium',
#    'inferior venae cava',
#    'pericardium',
#    'Cardiovascular diseases',
#    'blood',
#    'shortness of breath',
#    'heart disease',
#    'diabetes',
#    'pulmonary circulation',
#    'myocardium',
#    'coronary artery disease',
#    'carbon dioxide',
#    'chest pain',
#    'epicardium']},
#  {'context_id': 121,
#   'keywords': ['Thailand',
#    'Kingdom of Thailand',
#    'Siam',
#    'Laos',
#    'Cambodia',
#    'Vietnam',
#    'India',
#    'Andaman Sea',
#    'special administrative area',
#    'military',
#    'Gulf of Thailand',
#    'Bangkok',
#    'Myanmar',
#    'constitutional monarchy',
#    'de facto',
#    'dictatorship',
#    'Malaysia',
#    'Southeast Asian Indochinese peninsula',
#    'parliamentary democracy',
#    'Indonesia']},
#  {'context_id': 122,
#   'keywords': ['William James',
#    'Carl Lange',
#    'Emotional Perception',
#    'Autonomic Nervous System']},
#  {'context_id': 123,
#   'keywords': ['Safavids',
#    'Iran',
#    'Shiʻism',
#    'Persian Emperor',
#    'Khorasan',
#    'Iranian',
#    "Shah Isma'il",
#    'Euphrates',
#    'Persian Gulf',
#    'Īrān',
#    'Oxus']},
#  {'context_id': 124,
#   'keywords': ['Assyria',
#    'Assyrian Empire',
#    'Mesopotamia',
#    'Parthian Empire',
#    'Sasanian Empire',
#    'Syriac Christianity',
#    'ancient Near East',
#    'Levant',
#    'Iron Age',
#    'Church of the East',
#    'late',
#    'Mesopotamian',
#    'empire']},
#  {'context_id': 125,
#   'keywords': ['Hollywood',
#    'Film Industry',
#    'American Film Institute',
#    'LA Film School',
#    'NYFA',
#    'movies',
#    'film industry',
#    'film',
#    'United States cinema',
#    'Star Wars',
#    'Lightstorm Entertainment',
#    'Paramount Pictures',
#    '20th Century Fox',
#    'Metro-Goldwyn-Mayer',
#    'Titanic']},
#  {'context_id': 126,
#   'keywords': ['Western Feminist',
#    'Suffrage',
#    "Women's Liberation",
#    'right to vote',
#    'feminist',
#    "women's"]},
#  {'context_id': 127,
#   'keywords': ['Guwahati', 'Assam', 'Brahmaputra', 'India']},
#  {'context_id': 128,
#   'keywords': ['Nasir-ud-Din Muḥammad',
#    'Mughal Emperor',
#    'Safavid dynasty',
#    'Persia',
#    'Pakistan',
#    'India',
#    'Mughal Empire',
#    'Afghanistan',
#    'Humayun',
#    'Bangladesh',
#    'regnal name',
#    'Babur']},
#  {'context_id': 129,
#   'keywords': ['Major Boothroyd',
#    'Dr. No',
#    'From Russia with Love',
#    'Terence Young',
#    'Major',
#    'Desmond Llewelyn']},
#  {'context_id': 130,
#   'keywords': ['BOSS GNU/Linux',
#    'GNU',
#    'Linux',
#    'Debian',
#    'Bharat Operating System Solutions',
#    'EduBOSS',
#    'BOSS Advanced Server',
#    'GNU/',
#    'Linux distribution',
#    'BOSS']},
#  {'context_id': 131,
#   'keywords': ['Russian',
#    'East Slavic Language',
#    'Indo-European',
#    'Ukrainian',
#    'Belarusian',
#    'Rusyn',
#    'East Slavic languages',
#    'lexi',
#    "Kievan Rus'",
#    'Ukraine',
#    'Bulgari',
#    'Church Slavonic',
#    'Russia',
#    'lexical',
#    'Bulgarian']},
#  {'context_id': 132,
#   'keywords': ['Song Dynasty',
#    'China',
#    'Confucianism',
#    'Buddhism',
#    'Landscape Art',
#    'Porcelain',
#    'Emperor',
#    'Jin dynasty',
#    'Song dynasty',
#    'Ju',
#    'Jin–Song Wars',
#    'Bianjing',
#    'Tang',
#    'Huizong of Song']},
#  {'context_id': 133,
#   'keywords': ['Quran',
#    'Translation',
#    'African',
#    'Asian',
#    'European Languages',
#    'Pakistan',
#    'Hindu',
#    'Salman the Persian',
#    'Al']},
#  {'context_id': 134,
#   'keywords': ['Brazil',
#    'Germany',
#    'FIFA World Cup',
#    'Semi-finals',
#    'defender',
#    'man of the match',
#    'Neymar',
#    'time',
#    'Thiago Silva',
#    'goal',
#    'Toni Kroos']},
#  {'context_id': 135,
#   'keywords': ['Vedic Sanskrit',
#    'Vedas',
#    'Rigveda',
#    'Brahmi',
#    'Sanskrit',
#    'hymns',
#    'Hindu religion']},
#  {'context_id': 136,
#   'keywords': ['Imran Khan',
#    'Jaane Tu... Ya Jaane Na',
#    'Abbas Tyrewala',
#    'Aamir Khan',
#    'Filmfare Awards',
#    'Khalid Mohammed',
#    'Farhan Akhtar',
#    'CNN-IBN',
#    'Jhamu Sugandh',
#    'Rajeev Mas',
#    '54th',
#    'romantic comedy',
#    'time']},
#  {'context_id': 137,
#   'keywords': ['Colombians',
#    'Spanish Language',
#    'Amerindian Languages',
#    'Creole Languages',
#    'Romani Language',
#    'Santa Catalina',
#    'Romani language',
#    'Creole languages',
#    'San Andrés']},
#  {'context_id': 138,
#   'keywords': ['Smith',
#    'Oxford University',
#    'Rugby Union',
#    'Leicestershire County Cricket Club',
#    'Test',
#    'cricket',
#    'St Edmund Hall, Oxford',
#    'Stamford School',
#    'rugby union',
#    'Leicester',
#    'double international',
#    'Westcotes',
#    'Arthur Milton']},
#  {'context_id': 139,
#   'keywords': ['Tamil Nadu',
#    'India',
#    'Puducherry',
#    'Sri Lanka',
#    'Meghamalai Hills',
#    'Indian subcontinent',
#    'Madras State',
#    'Karnataka',
#    'Madras',
#    'Tamil Country',
#    'Palk Strait',
#    'Eastern Ghats',
#    'Indian Ocean',
#    'Bay of Bengal',
#    'Chennai',
#    'Gulf of Mannar',
#    'Tamiḻ Nāḍu',
#    'Nilgiri Mountains',
#    'Andhra Pradesh',
#    'union territory of',
#    'Kerala']},
#  {'context_id': 140,
#   'keywords': ['Hassan Rouhani',
#    'Iranian President',
#    'Iran',
#    'President of',
#    'Mahmoud Ahmadinejad']},
#  {'context_id': 141,
#   'keywords': ['Putin',
#    'Law',
#    'Anatoly Sobchak',
#    'Saint Petersburg State University',
#    'Leningrad State University',
#    'business law']},
#  {'context_id': 142,
#   'keywords': ['Sulfuric Acid',
#    'Bleaching Powder',
#    'Charles Tennant',
#    'chlorine',
#    'John Roebuck',
#    'saltpeter',
#    'Sulfuric acid',
#    'lime',
#    'Glasgow',
#    'Joshua Ward',
#    'bleaching powder',
#    'sulfuric acid',
#    'sulphuric acid',
#    'Samuel Garbett',
#    'bleaching',
#    'great chemical industrial enterprise',
#    'Prestonpans']},
#  {'context_id': 143,
#   'keywords': ['Arithmetical Investigations',
#    'Number Theory',
#    'Carl Friedrich Gauss',
#    'number theory',
#    'Euler']},
#  {'context_id': 144,
#   'keywords': ['Black Metal',
#    'Thrash Metal',
#    'Death Metal',
#    'Venom',
#    'Bathory',
#    'Mercyful Fate',
#    'Hellhammer',
#    'Emperor',
#    'Dark Funeral',
#    'Immortal',
#    'Gorgoroth',
#    'thrash metal',
#    'Satyricon',
#    'Europe',
#    'Nifelheim',
#    'Burzum',
#    'black metal',
#    'Darkthrone',
#    'death metal',
#    'Mayhem',
#    'Celtic Frost',
#    'Marduk']},
#  {'context_id': 145,
#   'keywords': ['Albert Einstein',
#    'Ashkenazi Jews',
#    'Catholic Elementary School',
#    'Luitpold Gymnasium',
#    'German Empire',
#    'Albert Einstein Gymnasium',
#    'Munich']},
#  {'context_id': 146,
#   'keywords': ['Portland',
#    'Oregon',
#    'Population',
#    'Multnomah County',
#    'Willamette Valley',
#    'Pacific Northwest',
#    'United',
#    'Portland metropolitan area',
#    'Willamette',
#    'Combined Statistical Area',
#    'Columbia',
#    'Portland metropolitan statistical area',
#    'Multnomah',
#    'Seattle']},
#  {'context_id': 147,
#   'keywords': ['Roger Federer',
#    'ATP Rankings',
#    "Men's Singles",
#    'Association of Tennis Professionals',
#    'Grand Slam',
#    'tennis',
#    '2017 Australian Open',
#    'ATP']},
#  {'context_id': 148,
#   'keywords': ['Subhas Chandra Bose',
#    'Orissa Division',
#    'Bengal Province',
#    'Jana',
#    'Kayastha',
#    'Cuttack',
#    'advocate']},
#  {'context_id': 149,
#   'keywords': ['Wallace',
#    'Evolutionary Theory',
#    'Geography',
#    'natural selection',
#    'biogeography',
#    'Mars',
#    'evolutionary theory',
#    'animal',
#    'Wallace effect']},
#  {'context_id': 150,
#   'keywords': ['Memphis',
#    'Archaeology',
#    'Jean de Thévenot',
#    'Thévenot',
#    'archaeology',
#    'Egypt',
#    'Napoléon Bonaparte']},
#  {'context_id': 151,
#   'keywords': ['South Asia',
#    'European Merchants',
#    'Vasco de Gama',
#    'Mughal Empire',
#    'Sikh Empire',
#    'British Empire',
#    'Hindu Kush',
#    'British empire',
#    'sultanate',
#    'India',
#    'World War II',
#    'Islamic',
#    'East Pakistan',
#    'East Bengal',
#    'Ranjit Singh',
#    'Aurangzeb',
#    'West Bengal',
#    'Bengal',
#    'Bangladesh',
#    'South']},
#  {'context_id': 152,
#   'keywords': ['Anushilan',
#    'Political Assassinations',
#    'Dacoities',
#    'London',
#    'Paris Indian Society',
#    'India House',
#    'Narendra Nath Bhattacharya',
#    'Anush',
#    'Khudiram Bose',
#    'Andrew Fraser',
#    'bomb',
#    'Aurobindo Ghosh',
#    'Calcutta',
#    'Nandalal Bannerjee',
#    'D.H. Kingsford',
#    'Prafulla Chaki',
#    'ass',
#    'time',
#    'Bengal',
#    'Maniktala',
#    'Muzaffarpur',
#    'Alipore Conspiracy trial',
#    'V. D. Savarkar',
#    'Nicholas Safranski',
#    'Paris']},
#  {'context_id': 153,
#   'keywords': ['Cairo',
#    'Egypt',
#    'World City',
#    'GaWC',
#    'Fatimid dynasty',
#    'Middle East',
#    'Islamic architecture',
#    'Ga',
#    'Africa',
#    'Giza pyramid complex',
#    'metropolitan area',
#    'Memphis',
#    'minarets',
#    'Nile Delta']},
#  {'context_id': 154,
#   'keywords': ['Mughal Emperor Akbar',
#    'Akbar Gate',
#    'Maseeti Gate',
#    'Akbari Gate',
#    'Mughal Emperor',
#    'Akbar']},
#  {'context_id': 155,
#   'keywords': ['Tibet',
#    'Qing Dynasty',
#    'Xinhai Revolution',
#    'Three Point Agreement',
#    'Lhasa',
#    'China',
#    'Qing dynasty',
#    'Mongolia',
#    'sovereignty',
#    'Republic of',
#    'Xinhai Lhasa']},
#  {'context_id': 156,
#   'keywords': ['Chief of Army Staff',
#    'Bangladesh Army',
#    'General Aziz Ahmed',
#    'Colonel',
#    'M. A. G. Osmani',
#    'General',
#    'Bangladesh Independence War',
#    'Bangladesh',
#    'Bangladesh army',
#    'Aziz Ahmed']},
#  {'context_id': 157,
#   'keywords': ['Darwin',
#    'Evolution',
#    'Natural Selection',
#    'natural selection',
#    'transmutation of species',
#    'life sciences',
#    'modern evolutionary synthesis']},
#  {'context_id': 158,
#   'keywords': ['Ayer was married four times to three women. His first marriage was from 1932–1941 to (Grace Isabel) Renée (d. 1980)',
#    'who subsequently married philosopher Stuart Hampshire',
#    "Ayer's friend and colleague. In 1960",
#    'Stuart Hampshire',
#    'columnist',
#    'Vanessa',
#    'Nigel Lawson',
#    'Sheilah Graham Westbrook',
#    'Dee Wells']},
#  {'context_id': 159,
#   'keywords': ['Democratic Republic of Congo',
#    'War Rape',
#    'Sexual Violence',
#    'Louise Nzigire',
#    'sexual violence',
#    'gang rape',
#    'Médecins Sans Frontières',
#    'rape',
#    'Bunia',
#    'War rape',
#    'Ituri']},
#  {'context_id': 160,
#   'keywords': ['Muslim Conquest',
#    'India',
#    'Hindu Caste System',
#    'Islam',
#    'Hindu']},
#  {'context_id': 161,
#   'keywords': ['Rashidun',
#    'Umayyad Caliphate',
#    'First Fitna',
#    'Khorasan',
#    'Caliphate',
#    'Armenia',
#    'Imam',
#    'Muawiyah',
#    'Sunni',
#    'Egypt',
#    'Muaw',
#    'Fitna',
#    'Sassanid Empire',
#    'caliphate',
#    'Arabian Peninsula',
#    'Abu Bakr',
#    'Umayyad',
#    'Ali',
#    'Muhammad',
#    'Uthman',
#    'Amr ibn al-As',
#    'caliph']},
#  {'context_id': 162,
#   'keywords': ['Uzbekistan',
#    'Landlocked Country',
#    'Constitutional Republic',
#    'Afghanistan',
#    'Turkmenistan',
#    'Tajikistan',
#    'landlocked country',
#    'Republic',
#    'Kyrgyzstan',
#    'Liechtenstein',
#    'Kazakhstan']},
#  {'context_id': 163,
#   'keywords': ['Chittagong',
#    'Portuguese Privateers',
#    'Arakanese Pirates',
#    'Mughal Empire',
#    'Pagan Invasion',
#    'Pala Empire',
#    'Sher Shah Suri',
#    'Keyakchu',
#    'Mrauk U dynasty',
#    'Batsauphyu (reign: 1459–',
#    'Arakan',
#    'Dharmapala',
#    'Mughal',
#    'Sur Dynasty',
#    'Ghiyasuddin Mahmud Shah',
#    'Fakhruddin Mubarak Shah',
#    'Bujurg Umed Khan',
#    'Sultan',
#    'Sonargaon',
#    'Bengal',
#    'Barbak Shah',
#    'Sitakunda',
#    'kanese',
#    'Sultanate of Bengal',
#    'Batsauphyu']},
#  {'context_id': 164,
#   'keywords': ['Bihar',
#    'Bureaucracy',
#    'Chief Secretary',
#    'Indian Administrative Service',
#    'Police Service',
#    'Indian Forest Service',
#    'Chief Justice',
#    'Patna',
#    'judiciary']},
#  {'context_id': 165,
#   'keywords': ['Emperor Yang of Sui',
#    'Yang Guang',
#    'Yang Tong',
#    'Emperor Ming',
#    'Emperor',
#    'Sui dynasty',
#    'China',
#    'Yang of Sui',
#    'Emperor Wen of Sui',
#    'Yang',
#    'emperor']},
#  {'context_id': 166,
#   'keywords': ['British Broadcasting Corporation',
#    'BBC',
#    'Public Service Broadcasting',
#    'public sector broadcasting',
#    'public service broadcaster',
#    'Broadcasting House']},
#  {'context_id': 167,
#   'keywords': ['Steven Paul Jobs',
#    'Apple',
#    'Pixar',
#    'NeXT',
#    'Walt Disney Company',
#    'Apple Inc.',
#    'Steve Wozniak',
#    'microcomputer']},
#  {'context_id': 168,
#   'keywords': ['Selim I',
#    'Ottoman Empire',
#    'Mamluk Sultanate',
#    'Egypt',
#    'Sultan',
#    'Hejaz',
#    'Tihamah',
#    'Ottoman Turkish',
#    'Selim']},
#  {'context_id': 169,
#   'keywords': ['Pittsburgh',
#    'Pennsylvania',
#    'County Seat',
#    'Allegheny County',
#    'Philadelphia',
#    'Commonwealth of Pennsylvania',
#    'county',
#    'Ohio Valley']},
#  {'context_id': 170,
#   'keywords': ['Sumerians',
#    'Akkadians',
#    'Babylonians',
#    'Assyrians',
#    'Middle East Civilization',
#    'Middle East',
#    'Mesopotamia',
#    'Iraq']},
#  {'context_id': 171,
#   'keywords': ['Han dynasty',
#    'Cao Cao',
#    'Cao Wei',
#    'Jin dynasty',
#    'Yellow Turban Rebellion',
#    'Dong Zhuo',
#    'Emperor',
#    'Han empire',
#    'warlord',
#    'Sun Quan',
#    'Liu Bei',
#    'emperor',
#    'Han Empire',
#    'Three Kingdoms era',
#    'history',
#    'Cao Pi',
#    'Battle of Red Cliffs',
#    'Shu Han',
#    'Eastern Wu',
#    'Han imperial court',
#    'China',
#    'empire']},
#  {'context_id': 172,
#   'keywords': ['Rugby Union',
#    'British Empire',
#    'France',
#    'rugby union',
#    'Australia, New Zealand',
#    'Tonga',
#    'Rugby union',
#    'Samoa',
#    'Madagascar, New Zealand',
#    'Fiji',
#    'Great Britain and']},
#  {'context_id': 173, 'keywords': ['Abortion', 'India']},
#  {'context_id': 174,
#   'keywords': ['Mexican Peso',
#    'MXP',
#    'Interest Rates',
#    'Inflation',
#    'ISO 4217:',
#    'Enrique Peña Nieto',
#    'Mexican peso parity',
#    'peso',
#    'inflation rate',
#    'US Dollar',
#    'Mexican peso',
#    'Mexico']},
#  {'context_id': 175,
#   'keywords': ['Harry Potter',
#    "Harry Potter and the Philosopher's Stone",
#    'young adult literature']},
#  {'context_id': 176,
#   'keywords': ['Fertilizers',
#    'Inorganic',
#    'Liquid',
#    'Irrigation Water',
#    'Fertilizer',
#    'ammonium nitrate',
#    'liquid fertilizer',
#    'irrigation',
#    'ammonia',
#    'potassium chloride',
#    'diammonium phosphate',
#    'fertilizer']},
#  {'context_id': 177,
#   'keywords': ['Yemen',
#    'Republic of Yemen',
#    'Arabian Peninsula',
#    'Socotra',
#    'Red Sea',
#    "Sana'a",
#    'Oman',
#    'Saudi Arabia',
#    'Gulf of Aden',
#    'Guardafui',
#    'Western Asia',
#    'Arabian Sea',
#    'Republic',
#    'sovereign state']},
#  {'context_id': 178,
#   'keywords': ['Qing Dynasty',
#    'Qing Emperors',
#    'Qing Emperor',
#    'Kangxi Emperor',
#    'Jiaqing Emperor',
#    'Tongzhi Emperor',
#    'Empress Dowager Cixi',
#    'Qianlong Emperor',
#    'Guangxu',
#    'Beijing',
#    'Qianlong',
#    'China',
#    'Nurhaci',
#    'imperial',
#    'Shunzhi Emperor']},
#  {'context_id': 179,
#   'keywords': ['Glasgow',
#    'Scotland',
#    'City Council',
#    'Lana',
#    'Glasgow City Council',
#    'Scots language',
#    'Glasgow City council',
#    'River Clyde',
#    'Glasgow patter']},
#  {'context_id': 180,
#   'keywords': ['Peacekeeping Mission',
#    'United Nations Truce Supervision Organization',
#    'UNTSO',
#    'Israel',
#    'Palestine',
#    'India',
#    'Pakistan',
#    'UNMOGIP',
#    'Arab states',
#    'United Kingdom',
#    'Israeli–Palestinian conflict',
#    'Israelis',
#    'Truce Supervision Organization',
#    'Military Observer Group in',
#    'United Nations',
#    'ceasefire']},
#  {'context_id': 181,
#   'keywords': ['Mexico',
#    'President',
#    'Armed Forces',
#    'President of Mexico',
#    'Andrés Manuel López Obrador']},
#  {'context_id': 182,
#   'keywords': ['Indian Subcontinent',
#    'Ghaznavids',
#    'Ghurids',
#    'Delhi Sultanate',
#    'Mughals',
#    'Bahmanids',
#    'sultanate',
#    'Indian',
#    'Jaunpur',
#    'Gujarat',
#    'Malwa',
#    'Hindu art',
#    'north Deccan',
#    'Bengal',
#    'Muizzi']},
#  {'context_id': 183,
#   'keywords': ['Smith laid the foundations of classical free market economic theory. "The Wealth of Nations" was a precursor to the modern academic discipline of Economics. In this and other works',
#    'he developed the concept of division of labour',
#    'competition',
#    'rational self-',
#    'division of labour',
#    'Jonathan Swift',
#    'William Hogarth',
#    'free market economic theory',
#    'economics',
#    'The Wealth of Nations']},
#  {'context_id': 184, 'keywords': ['Bhubaneswar', 'Odisha', 'India']},
#  {'context_id': 185,
#   'keywords': ['Cricket',
#    'International Cricket Council',
#    'Test Cricket',
#    'cricket',
#    'England',
#    'association football',
#    'Test cricket']},
#  {'context_id': 186,
#   'keywords': ['Jerusalem',
#    'World Heritage Site',
#    'Armenian',
#    'Christian',
#    'Jewish',
#    'Muslim Quarters',
#    'Christians',
#    'World Heritage in Danger',
#    '4th millennium BCE',
#    'Canaanite period',
#    'Israelite period',
#    'Jews',
#    'population',
#    'Iron Age',
#    'Kingdom of Judah',
#    'Palestinians',
#    'Suleiman the Magnificent',
#    'Canaanite',
#    'Muslims']},
#  {'context_id': 187,
#   'keywords': ['Puerto Rico',
#    'Population',
#    'United States Census',
#    '2010 United States Census']},
#  {'context_id': 188,
#   'keywords': ['Weddings',
#    'India',
#    'Religion',
#    'Personal Preferences',
#    'Hindu',
#    'bride']},
#  {'context_id': 189,
#   'keywords': ['Samarkand Kufic Quran',
#    'Uthman Quran',
#    'Samarkand codex',
#    'Tashkent Quran',
#    'Quran',
#    'Uthman',
#    'Hast Imam library',
#    'Kufic script',
#    'Uzbekistan',
#    'Iraq',
#    'Kufic',
#    'Tashkent',
#    'Samarkand',
#    'Samarkand manuscript and Tashkent']},
#  {'context_id': 190,
#   'keywords': ['Rowling',
#    'Rolls Royce',
#    'Rolls-Royce Aircraft Engineer',
#    'Louis Volant',
#    'Croix de Guerre',
#    "Légion d'honneur",
#    'Yate',
#    'Bristol',
#    'genealogy',
#    'Arbroath',
#    'Rolls-Royce',
#    'Gloucestershire',
#    'Dugald Campbell',
#    'Legion of Honour',
#    'Isle of Arran',
#    'Courcelles-le-Comte',
#    'croix de guerre',
#    "King's Cross Station"]},
#  {'context_id': 191,
#   'keywords': ["National Socialist German Workers' Party",
#    'NSDAP',
#    'Nazi Party',
#    "German Workers' Party",
#    'Freikorps',
#    'Marxist',
#    'communism',
#    'völkisch',
#    'nationalism',
#    'big',
#    'Nazism',
#    'paramilitary']},
#  {'context_id': 192,
#   'keywords': ['Gregorian Calendar',
#    'Solar Calendar',
#    'Leap Day',
#    'lendar year',
#    'Common Era',
#    'Anno Domini',
#    'Gregorian reform',
#    '29 February',
#    'calendar year',
#    '31 December',
#    'Roman Calendar',
#    'Gregorian calendar',
#    'calendar era',
#    'Julian calendar',
#    'solar calendar',
#    'leap year',
#    'Roman',
#    'leap day',
#    'Catholic Church',
#    'calendar date',
#    'modern period']},
#  {'context_id': 193,
#   'keywords': ['Needham',
#    'Unix shell scripts',
#    'IMDb',
#    'Movie Database',
#    'Unix',
#    'shell']},
#  {'context_id': 194,
#   'keywords': ['Voltage', 'Overhead Lines', 'Railway Locomotives']},
#  {'context_id': 195,
#   'keywords': ['King Gojong',
#    'Regent Heungseon Daewongun',
#    'French Campaign',
#    'Gunboat Diplomacy',
#    'Heungseon Daewongun',
#    'Andong Kim',
#    'gunboat diplomacy',
#    'Regent',
#    'Gojong',
#    'isolationism',
#    'Gyeongbok Palace']},
#  {'context_id': 196,
#   'keywords': ['Muslim Brotherhood',
#    'Sunni Islamist Organization',
#    'Terrorism',
#    'terrorist',
#    'Hassan al-Banna',
#    'Arab world',
#    'Saudi Arabia',
#    'United Arab Emirates',
#    'Hamas',
#    'Islamist',
#    'Syria',
#    'Sunni',
#    'Russia',
#    'Egypt',
#    'January Revolution']},
#  {'context_id': 197,
#   'keywords': ['Richard Owen',
#    'Medical Student',
#    'University of Edinburgh',
#    "St Bartholomew's Hospital",
#    'London',
#    'John Abernethy',
#    'surgeon',
#    'Lancaster Royal Grammar School',
#    'apothecary',
#    'Lancaster']},
#  {'context_id': 198,
#   'keywords': ['Whooping Cough',
#    'Bordetella pertussis',
#    'Vaccine',
#    'Antibiotics',
#    'common cold',
#    'pertussis',
#    'cough',
#    'clarithromycin',
#    'polymerase chain reaction',
#    'azithromycin',
#    'Pertussis',
#    'omycin',
#    'sulfamethoxazole',
#    'bacterium',
#    'Whooping cough',
#    'developing world',
#    'trimethoprim',
#    'erythromycin',
#    'erythr',
#    'pertussis vaccine']},
#  {'context_id': 199,
#   'keywords': ['COAS',
#    'General Bipin Rawat',
#    'Dalbir Singh',
#    'General',
#    'Bipin Rawat']},
#  {'context_id': 200,
#   'keywords': ['Suharto',
#    'Indonesia',
#    'Military Leader',
#    'Politician',
#    'Sukarno',
#    'dictator',
#    'President of Indonesia']},
#  {'context_id': 201,
#   'keywords': ['German Empire', 'Imperial Germany', 'Kaiser Wilhelm II']},
#  {'context_id': 202,
#   'keywords': ["Jehovah's Witnesses",
#    'Charles Taze Russell',
#    'Joseph Franklin Rutherford',
#    'Nathan Homer Knorr',
#    'Bible Student movement',
#    'Watch Tower Society']},
#  {'context_id': 203,
#   'keywords': ['Muslim Brotherhood',
#    'Egypt',
#    'State of Emergency',
#    'Supreme Leader Mohammed Badie',
#    'Mohammed Badie',
#    'Hazem Al Beblawi',
#    'Hazem Al Be',
#    'house arrest',
#    'sit-in',
#    'Mohamed Morsi',
#    'state of emergency',
#    'Al Jazeera',
#    'Hosni Mubarak',
#    'Rabaa sit-in',
#    'Sinai']},
#  {'context_id': 204,
#   'keywords': ['Governor-General',
#    'Pakistan',
# ...
#   'keywords': ['Khalji Dynasty',
#    'Delhi Sultanate',
#    'Malik Kafur',
#    'Khalji dynasty',
#    'Hindu',
#    'Sultanate',
#    'Islam',
#    'Alauddin Khalji',
#    'Khusro Khan']},
#  {'context_id': 927,
#   'keywords': ['Gregorian Calendar',
#    'Civil Calendar',
#    'Leap Years',
#    'Pope Gregory XIII',
#    'civil calendar',
#    'Gregorian calendar',
#    'calendar']},
#  {'context_id': 928,
#   'keywords': ['Megacities',
#    'Urban Agglomerations',
#    'Asia',
#    'Brazil',
#    'Pakistan',
#    'Shanghai',
#    'China',
#    'Tokyo',
#    'Jakarta']},
#  {'context_id': 929,
#   'keywords': ['Istanbul',
#    'Byzantine Emperors',
#    'Constantine the Great',
#    'Christian Emperor',
#    'Christianity',
#    'Roman Emperor',
#    'Greek East',
#    'Byzantine',
#    'Byzantine state',
#    'Constantinople',
#    'Constantine',
#    'polity',
#    'emperor']},
#  {'context_id': 930,
#   'keywords': ['Classical Music',
#    'Western Art Music',
#    'Liturgical Music',
#    'Secular Music',
#    'secular',
#    'Classical music',
#    'music',
#    'art music']},
#  {'context_id': 931,
#   'keywords': ['Tagore',
#    'Novels',
#    'Ghare Baire',
#    'Gora',
#    'Chaturanga',
#    'She',
#    'Jogajog']},
#  {'context_id': 932,
#   'keywords': ['X chromosome',
#    'Human Genome',
#    'Inheritance',
#    'Fibonacci numbers',
#    'human',
#    'Y chromosome']},
#  {'context_id': 933,
#   'keywords': ['India', 'Bangladesh', 'Citizenship', 'limbo', 'enclave']},
#  {'context_id': 934,
#   'keywords': ['Brock Edward Lesnar',
#    'WWE',
#    'Universal Champion',
#    'professional wrestler',
#    'professional football',
#    'mixed martial artist']},
#  {'context_id': 935,
#   'keywords': ['Forest Resources',
#    'Chittagong Hills',
#    'Sundarbans',
#    'mangrove',
#    'Bay of Bengal',
#    'deciduous',
#    'teak']},
#  {'context_id': 936,
#   'keywords': ['Hizla', 'Union', 'Wards', 'Mauzas', 'Mahallas']},
#  {'context_id': 937,
#   'keywords': ['Narendra Damodardas Modi',
#    'Prime Minister',
#    'India',
#    'Prime Minister of India',
#    'Rashtriya Swayamsevak Sangh',
#    'Chief Minister',
#    'Gujarat',
#    'Bharatiya Janata Party',
#    'Varanasi']},
#  {'context_id': 938,
#   'keywords': ['Library of Alexandria',
#    'Ancient History',
#    'Demetrius of Phalerum',
#    'pseudepigraphic',
#    'Alexandria',
#    'Aristeas',
#    'Aristotle',
#    'Athens',
#    'Ptolemy I Soter',
#    'Ptolemy II Philadelphus',
#    'Letter of Aristeas']},
#  {'context_id': 939,
#   'keywords': ['India',
#    'Air India',
#    'Tata Airlines',
#    'Civil Aviation',
#    'Ahmedabad',
#    'J. R. D. Tata',
#    'Bellary',
#    'Imperial Airways',
#    'Bombay',
#    'De Havilland',
#    'Tata Sons Ltd.',
#    'Royal Air Force',
#    'civil aviation',
#    'Karachi',
#    'Tata Group',
#    'Puss Moth',
#    'Nevill Vintcent',
#    'Madras',
#    'JRD Tata']},
#  {'context_id': 940,
#   'keywords': ['Dinar',
#    'Libyan Arab Foreign Bank',
#    'Central Bank of Libya',
#    'ISO 4217',
#    'ISO 4217 code',
#    'Libya',
#    'dīnār',
#    'Libyan dinar',
#    'Ali Mohammed',
#    'dirham',
#    'dinar',
#    'Reuters',
#    'currency']},
#  {'context_id': 941, 'keywords': ['Peshawar', 'Khyber Pakhtunkhwa', 'Bannu']},
#  {'context_id': 942,
#   'keywords': ['Indian-Pakistani War',
#    'East Pakistan',
#    'Bangladesh',
#    'Instrument of Surrender',
#    'Pakistan',
#    'India',
#    'Pakistan Armed Forces',
#    'Pakistan military',
#    'Dhaka']},
#  {'context_id': 943,
#   'keywords': ['Bengal',
#    'South Asia',
#    'Ganges-Brahmaputra delta',
#    'Himalayan states',
#    'Nepal',
#    'Bhutan',
#    'Burma',
#    'Indian subcontinent',
#    'Bay of Bengal',
#    'geopol',
#    'Himalayan',
#    'Ganges-Brahmaputra delta system']},
#  {'context_id': 944,
#   'keywords': ['Chongqing',
#    'Mountain City',
#    'Yangtze River',
#    'Jialing River',
#    'Yangtze',
#    'Tang dynasty',
#    'Jialing',
#    'epigram',
#    'Li Bai']},
#  {'context_id': 945,
#   'keywords': ['Aesthetic Theory',
#    'Ancient Greece',
#    'Plato',
#    'Aristotle',
#    'Plotinus']},
#  {'context_id': 946,
#   'keywords': ['Lung',
#    'Immunity',
#    'Phagocytosis',
#    'Goblet Cells',
#    'immunoglobulin A',
#    'dendritic cells',
#    'phagocytosis; and dendritic cells',
#    'adaptive immune system',
#    'lung',
#    'air-borne infection',
#    'phagocytosis']},
#  {'context_id': 947,
#   'keywords': ['Kyat',
#    'Myanmar',
#    'ISO 4217',
#    'MMK',
#    'kyat',
#    'Burma',
#    'currency']},
#  {'context_id': 948,
#   'keywords': ['Mein Kampf',
#    'Adolf Hitler',
#    'Nazi Party',
#    'Hitler',
#    'antisemitic',
#    'ideology',
#    'Rudolf Hess']},
#  {'context_id': 949,
#   'keywords': ['Ilkhanate',
#    'Mongol Empire',
#    'Genghis Khan',
#    'Hulagu Khan',
#    'Ghazan',
#    'Islam',
#    'Khwarazmian Empire',
#    'Afghanistan',
#    'Turkmenistan',
#    'Armenia',
#    'Iraq',
#    'Iran',
#    'Azerbaijan',
#    'khanate',
#    'Hulagu',
#    'Georgia',
#    'Turkey']},
#  {'context_id': 950,
#   'keywords': ['Ubuntu 5.10',
#    'Canonical',
#    'Breezy Badger',
#    'Usplash',
#    'Alacarte',
#    'Launchpad',
#    'Ubuntu',
#    'Hewlett-Packard',
#    'Ubuntu 5']},
#  {'context_id': 951,
#   'keywords': ['Paul Simon',
#    'Art Garfunkel',
#    'Songwriting',
#    'The Girl for Me',
#    'Library of Congress']},
#  {'context_id': 952,
#   'keywords': ['Hafez Sulayman al-Assad',
#    'Alawite',
#    'French Mandate',
#    'Syria',
#    'Ali',
#    'Sulayman al-Assad',
#    'French Mandate for Syria']},
#  {'context_id': 953,
#   'keywords': ['India',
#    'Language Families',
#    'Indo-Aryan',
#    'Dravidian',
#    'Austroasiatic',
#    'Sino-Tibetan',
#    'Sino-Tibetan language',
#    'Hindi']},
#  {'context_id': 954,
#   'keywords': ['Jawaharlal Nehru',
#    'Prime Minister',
#    'India',
#    'Freedom Fighter',
#    'Mahatma Gandhi',
#    'nation-state',
#    'Kashmir',
#    'republic',
#    'Pandit']},
#  {'context_id': 955,
#   'keywords': ['Jin dynasty',
#    'Great Jin',
#    'Wanyan Jurchen',
#    'Great',
#    'tone marker',
#    'Hanyu',
#    'China',
#    'Mongol invasion of China',
#    'Jin',
#    'Jìn dynasty',
#    'Pinyin']},
#  {'context_id': 956,
#   'keywords': ['Puranas',
#    'Oral Texts',
#    'Vedas',
#    'Ludo Rocher',
#    'Vishnu Purana',
#    'F. E. Pargiter',
#    'Markandeya Purana',
#    'purana',
#    'Vamana Purana',
#    'Vayu Purana',
#    'Purana',
#    'Matsya Purana',
#    'Vishnu',
#    'Linga Purana',
#    'Kurma Purana',
#    'Harivamsa',
#    'Brahmanda Purana',
#    'Bhagavata']},
#  {'context_id': 957,
#   'keywords': ['Pixar Animation Studios',
#    'Pixar',
#    'Disney',
#    'RenderMan',
#    'Computer Animation',
#    'Steve Jobs',
#    'Emeryville, California',
#    'Walt Disney Company',
#    'Lucasfilm',
#    'Apple Inc.',
#    'computer animation',
#    'Walt Disney Studios',
#    'application programming interface',
#    'C',
#    'subsidiary']},
#  {'context_id': 958,
#   'keywords': ['Awami League', 'Pakistan War', 'Pakistan', 'Pakistan Army']},
#  {'context_id': 959,
#   'keywords': ['European Scholarship',
#    'Sanskrit',
#    'Indo-European Language Family',
#    'Sir William Jones',
#    'Western philology',
#    'Heinrich Roth',
#    'William Jones',
#    'Johann Ernst Hanxleden',
#    'historical linguistics',
#    'Indo-European language']},
#  {'context_id': 960,
#   'keywords': ['Auckland',
#    'New Zealand',
#    'Urban Population',
#    'Polynesian Population',
#    'Auckland Council',
#    'Tāmaki',
#    'Polynesian',
#    'Māori',
#    'Auckland Region',
#    'Hauraki Gulf']},
#  {'context_id': 961,
#   'keywords': ['Tagore',
#    'Jorosanko',
#    'Maithili',
#    'Bhānusiṃha',
#    'Sandhya Sangit',
#    'Bhikharini']},
#  {'context_id': 962,
#   'keywords': ['Ceratopsian Research',
#    'Paleontology',
#    'ceratopsians',
#    'Triceratops',
#    'Bison',
#    'Othniel Charles Marsh',
#    'Ceratopsia',
#    'parrot',
#    'Tricera',
#    'Cerat',
#    'Edward Drinker Cope',
#    'paleontology']},
#  {'context_id': 963,
#   'keywords': ['Revenue Divisional Commissioner',
#    'Revenue',
#    'Sambalpur',
#    'Berhampur',
#    'Cuttack',
#    'Indian Administrative Service',
#    'revenue']},
#  {'context_id': 964,
#   'keywords': ['Karim Abdul-Jabbar',
#    'Dolphins',
#    'Lawsuit',
#    'running back',
#    'jersey',
#    'Miami Dolphins']},
#  {'context_id': 965,
#   'keywords': ['Cleopatra',
#    'Ancient Egyptian Culture',
#    'Victorian Britain',
#    'Alexander Pushkin',
#    'Georg Ebers',
#    'Egyptologist Yan Fu',
#    'Alexandria',
#    'George Bernard Shaw',
#    'pleasure barge',
#    'lithograph',
#    "One of Cleopatra's Nights",
#    'Egyptian culture',
#    'F. C. Burnand',
#    'burlesque',
#    'Yan Fu',
#    'Tarsus',
#    'Western world',
#    'Lawrence Alma-Tadema',
#    'Victorien Sardou',
#    'H. Rider Haggard',
#    'Middle East',
#    'dramatist',
#    'Antony and Cleopatra',
#    'Tar',
#    'Théophile Gautier',
#    'Aurelius Victor']},
#  {'context_id': 966,
#   'keywords': ['Ghaghara River',
#    'Sharda River',
#    'Ganges',
#    'Yamuna',
#    'Revelganj',
#    'Ghaghara',
#    'Tibetan Plateau',
#    'India',
#    'Lake Manasarovar',
#    'Karṇālī',
#    'Bihar',
#    'Karnali (; "Ghā',
#    'Nepal',
#    'confluence',
#    'river',
#    'Himalayas',
#    'Brahmaghat']},
#  {'context_id': 967,
#   'keywords': ['Bible',
#    'Codex Vaticanus',
#    'Codex Amiatinus',
#    'Tanakh',
#    'Hebrew',
#    'parchment',
#    'Aramaic',
#    'Vulgate',
#    'Vatican Library']},
#  {'context_id': 968,
#   'keywords': ['Hemachandra Suri',
#    'Jain Monk',
#    'Śvētāmbara School',
#    'Nagaur',
#    'Śvētāmbara',
#    'Jain',
#    'Devchandra Suri',
#    'Rajasthan',
#    'Magha',
#    'Jainism',
#    'acharya']},
#  {'context_id': 969,
#   'keywords': ['Atheism',
#    'Enlightenment',
#    'French Revolution',
#    'ancient Greek',
#    'Age of Enlightenment',
#    'atheist',
#    'skeptical inquiry',
#    'freethought']},
#  {'context_id': 970,
#   'keywords': ['Jyotirindra Basu',
#    'Kolkata',
#    'Mahatma Gandhi Road',
#    'housewife',
#    'Narayanganj District',
#    'Hindustan Road',
#    'East Bengal']},
#  {'context_id': 971,
#   'keywords': ['Nongthombam Biren Singh',
#    'Manipur Chief Minister',
#    'Chief Minister',
#    'Manipur']},
#  {'context_id': 972,
#   'keywords': ['North 24 Parganas',
#    'India',
#    'Census 2011',
#    'Thane District',
#    'Maharashtra',
#    'population growth rate',
#    'North 24 Parganas district',
#    'Thane district',
#    'North 24 Parganas District',
#    'Bolivia',
#    'literacy rate',
#    'population density']},
#  {'context_id': 973,
#   'keywords': ['DELAG',
#    'Deutsche Luftschiffahrts-Aktiengesellschaft I',
#    'Airships',
#    'The Zeppelin Corporation',
#    'fixed wing scheduled airline',
#    'Avianca',
#    'Zeppelin Corporation',
#    'Frankfurt',
#    'K',
#    'Czech Airlines',
#    'Tampa, Florida',
#    'Colombia',
#    'airship',
#    'St. Petersburg, Florida']},
#  {'context_id': 974,
#   'keywords': ['Kolkata-Agartala',
#    'Direct Bus',
#    'India',
#    'Bangladesh',
#    'Mamata Bannerjee',
#    'Kolkata',
#    'Chief Minister',
#    'Dhaka',
#    'service',
#    'Narendra Modi',
#    'West Bengal',
#    'Agartala',
#    'Sheikh Hasina']},
#  {'context_id': 975,
#   'keywords': ['President of Somalia',
#    'Armed Forces',
#    'Federal Republic of Somalia',
#    'Somali Armed Forces',
#    'Constitution of Somalia',
#    'head of state',
#    'Mohamed Abdullahi Mohamed ‘',
#    'Republic of',
#    'Somali nation',
#    'Somalia',
#    'Aden Abdullah Osman Daar']},
#  {'context_id': 976,
#   'keywords': ['Johannesburg',
#    'South Africa',
#    'Constitutional Court',
#    'Witwatersrand range',
#    'Gauteng',
#    'diamond']},
#  {'context_id': 977,
#   'keywords': ['Ajit Wadekar',
#    'India',
#    'ODI',
#    'T20I',
#    'M.S. Dhoni',
#    'Virendar Sehwag',
#    'Headingley',
#    'England',
#    'captain']},
#  {'context_id': 978,
#   'keywords': ['Gaya',
#    'Bihar',
#    'Tourism',
#    'Magadh',
#    'Mangla-Gauri',
#    'Phalgu River',
#    'Patna',
#    'Gaya district']},
#  {'context_id': 979,
#   'keywords': ['Hindu Philosophy',
#    'Sankhya',
#    'Yoga',
#    'Nyaya',
#    'Vaisheshika',
#    'Mimamsa',
#    'Vedanta',
#    'India',
#    'Buddhism',
#    'Cārvāka',
#    'world',
#    'Nāstika',
#    'Jainism',
#    'Ājīvika',
#    'Hindu philosophy',
#    'Vedas']},
#  {'context_id': 980,
#   'keywords': ['Chennai',
#    'India',
#    'Health Tourism',
#    'Chennai Metropolitan Area',
#    'urban agglomeration',
#    'Tamil Nadu',
#    'Bay of Bengal',
#    'metropolitan city',
#    'Coromandel Coast',
#    'Madras',
#    'urban']},
#  {'context_id': 981,
#   'keywords': ['Charles Babbage',
#    'Programmable Computer',
#    'Analytical Engine',
#    'Jacquard loom',
#    'arithmetic logic',
#    'polymath',
#    'integrated memory',
#    'Turing-complete']},
#  {'context_id': 982,
#   'keywords': ['Lebanon',
#    'Sovereign State',
#    'Western Asia',
#    'Mediterranean Sea',
#    'Israel',
#    'Lebanese Republic',
#    'Syria',
#    'Mediterranean Basin',
#    'Cyprus',
#    'sovereign state']},
#  {'context_id': 983,
#   'keywords': ['Arabic', 'Syria', 'Levantine', 'Mesopotamia', 'official']},
#  {'context_id': 984,
#   'keywords': ['Skin Pigmentation',
#    'Natural Selection',
#    'Genetics',
#    'genetics',
#    'natural selection',
#    'skin color',
#    'skin',
#    'ultraviolet',
#    'skin pigmentation']},
#  {'context_id': 985,
#   'keywords': ['Microsoft India Private Limited',
#    'Microsoft',
#    'Microsoft Corporation',
#    'Indian Government',
#    'IT Industry',
#    'Education',
#    'Developer Community',
#    'Ahmedabad',
#    'India',
#    'Kolkata',
#    'Chennai',
#    'Gurga',
#    'Pune',
#    'Bangalore',
#    'subsidiary',
#    'Kochi',
#    'Hyderabad',
#    'Microsoft India Private',
#    'software']},
#  {'context_id': 986,
#   'keywords': ['Coimbatore',
#    'Kovai',
#    'Tamil Nadu',
#    'urban agglomeration',
#    'India',
#    'Chennai',
#    'Western Ghats',
#    'Noyyal River',
#    'Coimbatore Municipal Corporation',
#    'Coimbatore district']},
#  {'context_id': 987,
#   'keywords': ['Marine Corps',
#    'DoD',
#    'Amphibious Warfare',
#    'amphibious warfare',
#    'Philadelphia',
#    'World War II']},
#  {'context_id': 988,
#   'keywords': ['Rabindranath Tagore',
#    'Bengali Literature',
#    'Contextual Modernism',
#    'Nobel Prize',
#    'Bengali literature',
#    'Modernism',
#    'Indian subcontinent',
#    'Nobel Prize in Literature',
#    'Bard',
#    'Bengal',
#    'Gitanjali']},
#  {'context_id': 989,
#   'keywords': ['Somali Shilling',
#    'ISO 4217: SOS',
#    'Currency',
#    'ISO 4217:',
#    'Somali shilling',
#    'official',
#    'Somalia',
#    'Somali',
#    'currency']},
#  {'context_id': 990,
#   'keywords': ['Doha', 'Qatar', 'Population Growth', 'Dōḥa', 'Persian Gulf']},
#  {'context_id': 991,
#   'keywords': ['Adam Ewing',
#    'Chatham Islands',
#    'California Gold Rush',
#    'Moriori Slave',
#    'Maori Overseeer',
#    'Autua',
#    'San Francisco',
#    'seaman',
#    'Hawaii',
#    'volcano']},
#  {'context_id': 992,
#   'keywords': ['Cave Painting',
#    'Neanderthal',
#    'Uranium-Thorium Method',
#    'East Kalimantan',
#    'uranium-thorium',
#    'red hand stencil',
#    'Borneo',
#    'cave',
#    'Sulawesi']},
#  {'context_id': 993,
#   'keywords': ['Poppy Seed',
#    'Oilseed',
#    'Central Europe',
#    'Poppy seed',
#    'Central',
#    'poppy',
#    'poppyseed oil']},
#  {'context_id': 994,
#   'keywords': ['Vatican City',
#    'Vatican City State',
#    'Rome',
#    'Lateran Treaty',
#    'Italy',
#    'city-state',
#    'Holy See',
#    'enclave']},
#  {'context_id': 995,
#   'keywords': ['Color Vision',
#    'Ishihara Color Test',
#    'Blue-yellow Color Blindness',
#    'Chromatopsia',
#    'color blind',
#    'total color blindness',
#    'X chromosome',
#    'blue-yellow color blindness',
#    'color test',
#    'color blindness',
#    'Red-green color blindness',
#    'achromatopsia',
#    'Color blindness',
#    'visual acuity']},
#  {'context_id': 996,
#   'keywords': ['Peru',
#    'National Football Team',
#    'FIFA',
#    'South American Football Confederation',
#    'CONMEBOL',
#    'Copa América',
#    'Peruvian Football Federation',
#    'Peru national football team',
#    'CONCACAF Gold Cup',
#    'Estadio Nacional',
#    'association football',
#    'Lima']},
#  {'context_id': 997,
#   'keywords': ['Civil Aviation',
#    'India',
#    'Henri Pequet',
#    'Air India',
#    'Humber',
#    'J.R.D. Tata',
#    'airmail',
#    'Allahabad Exhibition',
#    'civil aviation',
#    'Juhu Airport',
#    'Allahabad',
#    'Karachi',
#    'biplane',
#    'civil Aviation',
#    'Na']},
#  {'context_id': 998,
#   'keywords': ['South 24 Parganas',
#    'West Bengal',
#    'Sundarbans',
#    'India',
#    'Kolkata',
#    'Alipore',
#    'South Twenty Four Parganas']},
#  {'context_id': 999,
#   'keywords': ['Pyongyang',
#    "P'yŏngyang",
#    'North Korea',
#    'Yellow Sea',
#    'South Pyongan province',
#    'Taedong River',
#    "Pyongyang, or P'yŏngyang",
#    'Seoul',
#    'South Korea']},
#  ...]

# %%
with open('./data/BART_X_BERT_Keywords.json', 'w', encoding='utf-8') as file:
    json.dump(merged_list, file, ensure_ascii=False, indent=4)

# %%
text = data[0]['context']
text
# Out:
# 'WikiLeaks () is an international non-profit organisation that publishes secret information, news leaks, and classified media provided by anonymous sources. Its website, initiated in 2006 in Iceland by the organisation Sunshine Press, claims a database of 10 million documents in 10 years since its launch. Julian Assange, an Australian Internet activist, is generally described as its founder and director. Kristinn Hrafnsson is its editor-in-chief.'

# %%
keyword_extractor(text)
# Out:
# [{'generated_text': 'WikiLeaks, News Leaks, Sunshine Press'}]

# %%
# text = "Your input text here"
inputs = bart_tokenizer.encode(text, return_tensors="pt")
outputs = bart_model.generate(inputs, output_scores=True, return_dict_in_generate=True)
scores = outputs['scores']  # 每步的分数（概率分布）

# %%
import torch
import torch.nn.functional as F

# 假设 scores 是您的模型输出
scores_example = scores[0]  # 以第一个时间步的输出为例

# 应用 Softmax 来获取概率分布
probabilities = F.softmax(scores_example, dim=-1)

# 找出每个时间步概率最高的词的索引
max_indices = torch.argmax(probabilities, dim=-1)

# 解码为词
decoded_words = [bart_tokenizer.decode([idx], skip_special_tokens=True) for idx in max_indices]

print(decoded_words)
# Out:
# ['', '', '', '']

# %%
import torch
import torch.nn.functional as F

# 假设我们处理第一个时间步的输出，这里采用循环来处理所有时间步
for scores_tensor in scores:
    # 应用 Softmax 来获取概率分布
    probabilities = F.softmax(scores_tensor, dim=-1)

    # 对每个时间步，找出概率最高的词的索引
    max_indices = torch.argmax(probabilities, dim=-1)

    decoded_words = []
    for idx in max_indices:
        # 解码每个索引，跳过特殊标记
        word = bart_tokenizer.decode(idx, skip_special_tokens=True)
        if word:  # 确保解码的词不为空
            decoded_words.append(word)
    
    print(decoded_words)
# Out:
# []
# ['Wiki', 'Wiki', 'Wiki', 'Wiki']
# ['Leaks', 'Wiki', 'ileaks', 'Wiki']
# [',', 'Leaks', ',', 'Leaks']
# [' News', ',', ' News', ' News']
# [' Le', ' Le', ' Information', '-']
# ['aks', 'ak', ',', 'profit']
# [',', ' News', ',', ',']
# [' Sunshine', ' Le', ' News', ' News']
# ['aks', ' Press', ' Le', ' Le']
# [',', 'aks', 'aks']
# [' Sunshine', ' Julian', ',']
# [' Sunshine', ' Assange', ' Press', ' Media']
# [' Press', ' Media']

# %%
keywords = []
for i in tqdm(range(len(data))):
    text = data[i]['context']
    num_tokens = len(bart_tokenizer.encode(text))
    if num_tokens >= 1024:
        split_texts = text_splitter.create_documents([data[i]['context']])
        sub_keys = []
        for t in split_texts:
            sub_keys.append(keyword_extractor(t.page_content)[0]['generated_text'])
        keywords.append(sub_keys)
    else:
        keywords.append(keyword_extractor(text)[0]['generated_text'])
